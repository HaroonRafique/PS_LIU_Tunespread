# %% [markdown]
# # 10: LIU Ramp-Up: 2021 Long Term Tracking: SC

# %%
import imageio
import pickle
import pandas as pd
import numpy as np
import PyNAFF as pnf
import scipy.io as sio 
import matplotlib.cm as cm
from math import log10, floor
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from matplotlib.patches import Patch
from scipy.optimize import curve_fit

# %% [markdown]
# ### Figure parameters

# %%
plt.rcParams['figure.figsize'] = [5.0, 4.5]
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300

plt.rcParams['axes.titlesize'] = 14
plt.rcParams['axes.labelsize'] = 14

plt.rcParams['xtick.labelsize'] = 10
plt.rcParams['ytick.labelsize'] = 10

plt.rcParams['font.size'] = 10
plt.rcParams['legend.fontsize'] = 10

plt.rcParams['lines.linewidth'] = 1.5
plt.rcParams['lines.markersize'] = 5

# %% [markdown]
# ### Function Declarations

# %%
def harmonic_fn(x, a, b, c, d):
    return a + b*np.cos(c + 2*np.pi*d*x)

def quadratic(x, a, m, c):
    return a*x**2 + x*m + c

def quadratic(x, a, m, c):
    return a*x**2 + x*m + c

def Md_fit(x, a, b, c, d):
        return a + b*np.cos(c*x+d)
    
def Md_ramp_fit(x, a, b, c, d):
    return a + b*(x-1)*np.cos(c*(x-1)+d)

def round_sig(x, sig=4):
    return round(x, sig-int(floor(log10(abs(x))))-1)

# %%
def add_input_file(dd, filename, label):
	f = filename
	p = dict()
	sio.loadmat(f, mdict=p)
	dd[label] = p	
	print '\tAdded output data from ', filename, '\t dictionary key: ', label
	return dd

# %% [markdown]
# ## Import Data

# %%
#Horizontal Scan No Space Charge

# Create dd dictionary
dd = dict()


dd = add_input_file(dd, '00/output/output.mat', '0 %')
dd = add_input_file(dd, '05/output/output.mat', '5 %')
dd = add_input_file(dd, '10/output/output.mat', '10 %')
# Out:
# 	Added output data from  00/output/output.mat 	 dictionary key:  0 %
# 	Added output data from  05/output/output.mat 	 dictionary key:  5 %
# 	Added output data from  10/output/output.mat 	 dictionary key:  10 %

# %% [markdown]
# ### Plot Parameters

# %%
save_folder = 'Plots/'

sc = 'SbS'
legend_label = r'$\frac{\Delta \beta}{\beta_0}$' # r'$\frac{\delta p}{p_0}$'
main_label = 'PS_LIU_2021'
main_label2 = main_label + '_zoom'
scaled_label = main_label + '_scaled'
turn_tot = 5000
zoom_turns = 50
betagamma = 3.13154090774 * 0.947643035549 # 2GeV
#betagamma = 2.492104532 * 0.9159915293879255 # 1.4GeV

# %%
dd
# Out:
# {'0 %': {'D_x': array([[3.12705879, 3.22093994, 3.36710246, ..., 3.25490716, 3.25696765,
#           3.26460416]]),
#   'D_y': array([[-0.00269596, -0.0051078 , -0.00560179, ...,  0.00280391,
#            0.00308587,  0.00172846]]),
#   '__globals__': [],
#   '__header__': 'MATLAB 5.0 MAT-file Platform: posix, Created on: Sun Feb 23 16:15:54 2020',
#   '__version__': '1.0',
#   'alpha_x': array([[0.03021035, 0.02838221, 0.03798833, ..., 0.02805794, 0.02345999,
#           0.02357658]]),
#   'alpha_y': array([[0.05180475, 0.01312305, 0.0566337 , ..., 0.05922275, 0.05854163,
#           0.06131643]]),
#   'beta_x': array([[22.46924304, 22.51855021, 22.45839209, ..., 22.36836406,
#           22.35969477, 22.44323706]]),
#   'beta_y': array([[11.69305703, 12.31045643, 12.66421372, ..., 12.25548667,
#           12.24853078, 12.23840035]]),
#   'bunchlength': array([[1.21517983e-07, 1.21518581e-07, 1.21520308e-07, ...,
#           1.25728069e-07, 1.25732584e-07, 1.25737487e-07]]),
#   'cumulative_time': array([[1.96218491e-04, 9.27420220e+01, 1.95575202e+02, ...,
#           2.76540395e+05, 2.76632092e+05, 2.76723739e+05]]),
#   'dpp_rms': array([[0.00122504, 0.00122504, 0.00122503, ..., 0.00119071, 0.00119067,
#           0.00119062]]),
#   'eff_alpha_x': array([[ 0.02650685, -0.00406951,  0.01352371, ...,  0.02677675,
#            0.02171691,  0.02179224]]),
#   'eff_alpha_y': array([[0.05180265, 0.01312133, 0.05663519, ..., 0.05922251, 0.05854253,
#           0.06131739]]),
#   'eff_beta_x': array([[32.03279251, 32.55193293, 33.27096229, ..., 31.88804737,
#           31.88996718, 32.01732296]]),
#   'eff_beta_y': array([[11.69304869, 12.31048353, 12.6642489 , ..., 12.25549442,
#           12.24853772, 12.23839116]]),
#   'eff_epsn_x': array([[9.01620839e-07, 9.15658936e-07, 9.38212993e-07, ...,
#           9.27199677e-07, 9.27477578e-07, 9.27589578e-07]]),
#   'eff_epsn_y': array([[6.33515600e-07, 6.33808274e-07, 6.34758078e-07, ...,
#           6.88483904e-07, 6.88575354e-07, 6.88671314e-07]]),
#   'eps_z': array([[1.23400377, 1.23400308, 1.2340031 , ..., 1.24094846, 1.24094222,
#           1.24093574]]),
#   'epsn_x': array([[1.87631220e-06, 1.87625461e-06, 1.87652551e-06, ...,
#           1.92978486e-06, 1.92956842e-06, 1.92930273e-06]]),
#   'epsn_y': array([[1.88000595e-06, 1.88087330e-06, 1.88369141e-06, ...,
#           2.04313165e-06, 2.04340233e-06, 2.04368665e-06]]),
#   'gamma': array([[3.13154087, 3.13154087, 3.13154087, ..., 3.13154087, 3.13154087,
#           3.13154087]]),
#   'intensity': array([[3.25e+12, 3.25e+12, 3.25e+12, ..., 3.25e+12, 3.25e+12, 3.25e+12]]),
#   'kurtosis_dE': array([[-0.85253897, -0.8525132 , -0.85248812, ..., -0.89231017,
#           -0.89201686, -0.89172028]]),
#   'kurtosis_dE_6sig': array([[-0.85253897, -0.8525132 , -0.85248812, ..., -0.89231017,
#           -0.89201686, -0.89172028]]),
#   'kurtosis_x': array([[-0.21177346, -0.23856309, -0.27325998, ..., -0.26265169,
#           -0.26295526, -0.2603215 ]]),
#   'kurtosis_x_6sig': array([[-0.21177346, -0.23856309, -0.27325998, ..., -0.26265169,
#           -0.26295526, -0.2603215 ]]),
#   'kurtosis_xp': array([[ 0.00107818, -0.01399547, -0.01240947, ..., -0.05595368,
#           -0.07029201, -0.07203292]]),
#   'kurtosis_xp_6sig': array([[ 0.00107818, -0.01399547, -0.01240947, ..., -0.05595368,
#           -0.07029201, -0.07203292]]),
#   'kurtosis_y': array([[-0.01515008, -0.00418848, -0.05630052, ..., -0.24651394,
#           -0.25757311, -0.25275352]]),
#   'kurtosis_y_6sig': array([[-0.01515008, -0.00418848, -0.05630052, ..., -0.24651394,
#           -0.25757311, -0.25275352]]),
#   'kurtosis_yp': array([[ 0.00310356, -0.01602377,  0.0560175 , ..., -0.17572393,
#           -0.1687246 , -0.17503511]]),
#   'kurtosis_yp_6sig': array([[ 0.00310356, -0.01602377,  0.0560175 , ..., -0.17572393,
#           -0.1687246 , -0.17503511]]),
#   'kurtosis_z': array([[-0.86800699, -0.86802501, -0.86803829, ..., -0.83007795,
#           -0.83036634, -0.8306558 ]]),
#   'kurtosis_z_6sig': array([[-0.86800699, -0.86802501, -0.86803829, ..., -0.83007795,
#           -0.83036634, -0.8306558 ]]),
#   'max_dE': array([[0.00721343, 0.00721405, 0.00721401, ..., 0.0071838 , 0.00718669,
#           0.00718937]]),
#   'max_x': array([[0.02418259, 0.02260416, 0.02560935, ..., 0.02234134, 0.0227649 ,
#           0.02233299]]),
#   'max_xp': array([[0.00074136, 0.00077749, 0.00081511, ..., 0.00080324, 0.00086018,
#           0.00076832]]),
#   'max_y': array([[0.0128607 , 0.01248106, 0.01274613, ..., 0.01441537, 0.01310095,
#           0.01266315]]),
#   'max_yp': array([[0.00102612, 0.00100105, 0.0011027 , ..., 0.00105419, 0.00117016,
#           0.001021  ]]),
#   'max_z': array([[19.12787006, 19.11960889, 19.1144074 , ..., 20.39558044,
#           20.41319721, 20.43149193]]),
#   'mean_dE': array([[-1.31909773e-05, -1.31906873e-05, -1.31891277e-05, ...,
#            1.91191563e-05,  1.90901917e-05,  1.90606372e-05]]),
#   'mean_x': array([[-2.22410046e-05, -2.35451609e-05, -2.75552102e-05, ...,
#            7.17276283e-06,  4.55539243e-05,  3.37965028e-05]]),
#   'mean_xp': array([[ 1.17980572e-08, -1.20865299e-07, -1.66446485e-07, ...,
#            1.59469214e-06,  5.64688264e-07, -1.32682707e-06]]),
#   'mean_y': array([[ 5.79969617e-07, -1.36216842e-06, -8.69188483e-07, ...,
#            1.36538682e-06,  5.89457856e-08, -1.22555018e-06]]),
#   'mean_yp': array([[-1.19940569e-07, -5.75103653e-08,  1.10075068e-07, ...,
#           -1.08319050e-08, -1.13196906e-07, -2.71516756e-09]]),
#   'mean_z': array([[0.00186299, 0.00146945, 0.00107622, ..., 0.01531106, 0.01549848,
#           0.01568265]]),
#   'min_dE': array([[-0.00724008, -0.00724315, -0.00724763, ..., -0.00706939,
#           -0.00707655, -0.00708353]]),
#   'min_x': array([[-0.0230374 , -0.02424465, -0.02234171, ..., -0.02327014,
#           -0.02216747, -0.02293657]]),
#   'min_xp': array([[-0.00075847, -0.00077551, -0.00076636, ..., -0.00079918,
#           -0.00080794, -0.00081173]]),
#   'min_y': array([[-0.01204977, -0.01294162, -0.01221284, ..., -0.01421845,
#           -0.0134016 , -0.01627008]]),
#   'min_yp': array([[-0.00111678, -0.00102826, -0.00109709, ..., -0.00117553,
#           -0.00125648, -0.00106412]]),
#   'min_z': array([[-19.13138358, -19.12550935, -19.13090525, ..., -20.52411198,
#           -20.53521798, -20.54583408]]),
#   'mu_dE': array([[1.04484862e-05, 1.04484389e-05, 1.04482477e-05, ...,
#           9.87110398e-06, 9.87037358e-06, 9.86958358e-06]]),
#   'mu_x': array([[2.88814333e-05, 2.98064683e-05, 3.12152491e-05, ...,
#           2.95665872e-05, 2.95772295e-05, 2.96989351e-05]]),
#   'mu_xp': array([[2.81665837e-08, 2.81296383e-08, 2.82043115e-08, ...,
#           2.90975632e-08, 2.90973958e-08, 2.89852494e-08]]),
#   'mu_y': array([[7.40772875e-06, 7.80248632e-06, 8.03873429e-06, ...,
#           8.43771065e-06, 8.43404119e-06, 8.42822892e-06]]),
#   'mu_yp': array([[5.43242113e-08, 5.14941102e-08, 5.02828157e-08, ...,
#           5.63746026e-08, 5.64096118e-08, 5.64829630e-08]]),
#   'mu_z': array([[74.48898823, 74.48972189, 74.49183843, ..., 79.73985938,
#           79.74558614, 79.75180605]]),
#   'n_mp': array([[500000, 500000, 500000, ..., 500000, 500000, 500000]]),
#   'sig_dE': array([[0.00323241, 0.0032324 , 0.00323237, ..., 0.00314183, 0.00314172,
#           0.00314159]]),
#   'sig_x': array([[0.00537414, 0.00545953, 0.00558706, ..., 0.00543752, 0.0054385 ,
#           0.00544967]]),
#   'sig_xp': array([[0.00016783, 0.00016772, 0.00016794, ..., 0.00017058, 0.00017058,
#           0.00017025]]),
#   'sig_y': array([[0.00272171, 0.00279329, 0.00283527, ..., 0.00290477, 0.00290414,
#           0.00290314]]),
#   'sig_yp': array([[0.00023308, 0.00022692, 0.00022424, ..., 0.00023743, 0.00023751,
#           0.00023766]]),
#   'sig_z': array([[8.63070033, 8.63074284, 8.63086545, ..., 8.92971777, 8.93003842,
#           8.93038667]]),
#   'turn': array([[  -1,    0,    1, ..., 5997, 5998, 5999]]),
#   'turn_duration': array([[1.92880630e-04, 9.27417681e+01, 9.27838612e+01, ...,
#           9.15515521e+01, 9.16966701e+01, 9.16472340e+01]]),
#   'turn_time': array([u'17:53:06', u'17:54:39', u'17:56:22', ..., u'16:12:41',
#          u'16:14:12', u'16:15:44'], dtype='<U8')},
#  '10 %': {'D_x': array([[3.05557172, 3.19165456, 3.34148667, ..., 3.18127013, 3.18114645,
#           3.19807875]]),
#   'D_y': array([[-0.00261388,  0.00081067,  0.00242945, ...,  0.00075955,
#            0.00279846,  0.00376769]]),
#   '__globals__': [],
#   '__header__': 'MATLAB 5.0 MAT-file Platform: posix, Created on: Sun Feb 23 17:14:59 2020',
#   '__version__': '1.0',
#   'alpha_x': array([[0.000505  , 0.07070148, 0.11662978, ..., 0.0242977 , 0.03020622,
#           0.02678729]]),
#   'alpha_y': array([[ 0.11433912, -0.03404823,  0.02351023, ...,  0.05461846,
#            0.0752012 ,  0.05489556]]),
#   'beta_x': array([[21.17939267, 21.27882302, 20.15272672, ..., 19.89811585,
#           19.97437401, 19.97756602]]),
#   'beta_y': array([[12.80116059, 13.3799197 , 14.87261567, ..., 13.83004335,
#           13.98315805, 13.87618538]]),
#   'bunchlength': array([[1.21562511e-07, 1.21562937e-07, 1.21564463e-07, ...,
#           1.25925351e-07, 1.25923765e-07, 1.25922554e-07]]),
#   'cumulative_time': array([[1.91926956e-04, 9.43525128e+01, 1.98427783e+02, ...,
#           2.80074863e+05, 2.80167964e+05, 2.80260794e+05]]),
#   'dpp_rms': array([[0.00122349, 0.00122348, 0.00122347, ..., 0.00118772, 0.00118772,
#           0.00118772]]),
#   'eff_alpha_x': array([[0.07859812, 0.10432176, 0.15356041, ..., 0.10705033, 0.1076522 ,
#           0.10319696]]),
#   'eff_alpha_y': array([[ 0.11434129, -0.03404878,  0.02350959, ...,  0.05461781,
#            0.07519991,  0.05489504]]),
#   'eff_beta_x': array([[30.17043525, 31.05496743, 30.58127047, ..., 28.48903697,
#           28.58350485, 28.66478967]]),
#   'eff_beta_y': array([[12.80114057, 13.37989905, 14.87261922, ..., 13.83001929,
#           13.98315613, 13.87619895]]),
#   'eff_epsn_x': array([[9.08164871e-07, 9.25570164e-07, 9.65741922e-07, ...,
#           9.73869942e-07, 9.72449075e-07, 9.75109804e-07]]),
#   'eff_epsn_y': array([[6.33976821e-07, 6.35166500e-07, 6.40397395e-07, ...,
#           6.82725180e-07, 6.82676003e-07, 6.82781803e-07]]),
#   'eps_z': array([[1.2328908 , 1.23288935, 1.2328883 , ..., 1.2398005 , 1.23979164,
#           1.23978246]]),
#   'epsn_x': array([[1.88088455e-06, 1.88203733e-06, 1.88781504e-06, ...,
#           2.00859956e-06, 2.00870780e-06, 2.00881357e-06]]),
#   'epsn_y': array([[1.88137346e-06, 1.88490611e-06, 1.90043105e-06, ...,
#           2.02603987e-06, 2.02589501e-06, 2.02620930e-06]]),
#   'gamma': array([[3.13154087, 3.13154087, 3.13154087, ..., 3.13154087, 3.13154087,
#           3.13154087]]),
#   'intensity': array([[3.25e+12, 3.25e+12, 3.25e+12, ..., 3.25e+12, 3.25e+12, 3.25e+12]]),
#   'kurtosis_dE': array([[-0.84980452, -0.84977926, -0.84975611, ..., -0.88868633,
#           -0.88848902, -0.88829002]]),
#   'kurtosis_dE_6sig': array([[-0.84980452, -0.84977926, -0.84975611, ..., -0.88868633,
#           -0.88848902, -0.88829002]]),
#   'kurtosis_x': array([[-0.21791537, -0.25010888, -0.29635281, ..., -0.27531428,
#           -0.27771703, -0.28410323]]),
#   'kurtosis_x_6sig': array([[-0.21791537, -0.25010888, -0.29635281, ..., -0.27531428,
#           -0.27771703, -0.28410323]]),
#   'kurtosis_xp': array([[-0.00704901,  0.01204781,  0.00492206, ..., -0.14252622,
#           -0.14921299, -0.14372158]]),
#   'kurtosis_xp_6sig': array([[-0.00704901,  0.01204781,  0.00492206, ..., -0.14252622,
#           -0.14921299, -0.14372158]]),
#   'kurtosis_y': array([[ 0.00575688,  0.02235183, -0.08229791, ..., -0.15628529,
#            0.07383174, -0.14896406]]),
#   'kurtosis_y_6sig': array([[ 0.00575688,  0.02235183, -0.08229791, ..., -0.21649858,
#           -0.21076765, -0.2220005 ]]),
#   'kurtosis_yp': array([[-0.00495551, -0.03900828,  0.08266872, ...,  0.29533076,
#            0.11728594,  0.26944656]]),
#   'kurtosis_yp_6sig': array([[-0.00495551, -0.03900828,  0.08266872, ..., -0.01964392,
#           -0.04093124, -0.01682068]]),
#   'kurtosis_z': array([[-0.87050572, -0.87052398, -0.87053736, ..., -0.8279523 ,
#           -0.82830341, -0.82865753]]),
#   'kurtosis_z_6sig': array([[-0.87050572, -0.87052398, -0.87053736, ..., -0.8279523 ,
#           -0.82830341, -0.82865753]]),
#   'max_dE': array([[0.00721458, 0.00721548, 0.00721562, ..., 0.00732218, 0.00732564,
#           0.00732849]]),
#   'max_x': array([[0.02409271, 0.02099848, 0.02100711, ..., 0.02254734, 0.02116069,
#           0.02159418]]),
#   'max_xp': array([[0.00083337, 0.00085283, 0.00086118, ..., 0.00090862, 0.00089432,
#           0.00077479]]),
#   'max_y': array([[0.01325797, 0.01281699, 0.01393097, ..., 0.03751905, 0.05969787,
#           0.02049137]]),
#   'max_yp': array([[0.000979  , 0.00100172, 0.00098219, ..., 0.00438912, 0.00163572,
#           0.00181764]]),
#   'max_z': array([[19.13667816, 19.12301431, 19.12556669, ..., 20.66048126,
#           20.65324399, 20.64391075]]),
#   'mean_dE': array([[-7.90922224e-06, -7.86384856e-06, -7.81782359e-06, ...,
#            1.65471631e-05,  1.64951906e-05,  1.64428477e-05]]),
#   'mean_x': array([[-1.63001936e-05, -2.18987372e-05, -2.46852866e-05, ...,
#            1.45131734e-05, -9.62520365e-06, -9.41352378e-06]]),
#   'mean_xp': array([[-5.41178462e-09,  1.25530951e-08,  1.87599308e-07, ...,
#           -8.80326354e-07, -5.02055806e-07,  6.94581447e-07]]),
#   'mean_y': array([[-9.29607539e-06, -3.55849113e-07,  9.41162768e-06, ...,
#           -6.56592512e-06, -1.57153430e-06,  6.91688536e-06]]),
#   'mean_yp': array([[ 9.74459257e-09,  7.40395202e-07, -9.88950372e-08, ...,
#           -9.94000738e-08,  5.46098056e-07,  3.20130158e-08]]),
#   'mean_z': array([[-0.01575698, -0.01605454, -0.01635092, ...,  0.0262571 ,
#            0.02640301,  0.02655088]]),
#   'min_dE': array([[-0.00723948, -0.00724174, -0.0072446 , ..., -0.00711318,
#           -0.00710455, -0.00709562]]),
#   'min_x': array([[-0.02199041, -0.02358034, -0.02344413, ..., -0.0223533 ,
#           -0.02138468, -0.02342023]]),
#   'min_xp': array([[-0.0008289 , -0.00080306, -0.00082739, ..., -0.0008854 ,
#           -0.00095509, -0.00077757]]),
#   'min_y': array([[-0.01314663, -0.01265499, -0.01339958, ..., -0.02098536,
#           -0.02372159, -0.03979019]]),
#   'min_yp': array([[-0.00099807, -0.00097901, -0.00099831, ..., -0.00182243,
#           -0.00352219, -0.00427036]]),
#   'min_z': array([[-19.12459947, -19.1226448 , -19.12210839, ..., -20.95391929,
#           -20.95555143, -20.95792438]]),
#   'mu_dE': array([[1.04220014e-05, 1.04219636e-05, 1.04217803e-05, ...,
#           9.82149556e-06, 9.82160045e-06, 9.82164612e-06]]),
#   'mu_x': array([[2.73997294e-05, 2.87435513e-05, 2.95336149e-05, ...,
#           2.77446168e-05, 2.77960029e-05, 2.79513174e-05]]),
#   'mu_xp': array([[3.02871073e-08, 3.01286154e-08, 3.23241929e-08, ...,
#           3.45757658e-08, 3.44156110e-08, 3.43799608e-08]]),
#   'mu_y': array([[8.11562640e-06, 8.49846364e-06, 9.52438661e-06, ...,
#           9.44210241e-06, 9.54596513e-06, 9.47441614e-06]]),
#   'mu_yp': array([[5.01725129e-08, 4.75267308e-08, 4.30826161e-08, ...,
#           4.95127163e-08, 4.90973960e-08, 4.93535258e-08]]),
#   'mu_z': array([[74.54358926, 74.54411175, 74.54598245, ..., 79.99029758,
#           79.98828286, 79.98674421]]),
#   'n_mp': array([[500000, 500000, 500000, ..., 500000, 500000, 500000]]),
#   'sig_dE': array([[0.00322831, 0.00322831, 0.00322828, ..., 0.00313393, 0.00313394,
#           0.00313395]]),
#   'sig_x': array([[0.00523448, 0.0053613 , 0.00543448, ..., 0.00526732, 0.00527219,
#           0.0052869 ]]),
#   'sig_xp': array([[0.00017403, 0.00017358, 0.00017979, ..., 0.00018595, 0.00018551,
#           0.00018542]]),
#   'sig_y': array([[0.00284879, 0.00291521, 0.00308616, ..., 0.0030728 , 0.00308965,
#           0.00307805]]),
#   'sig_yp': array([[0.00022399, 0.00021801, 0.00020756, ..., 0.00022251, 0.00022158,
#           0.00022216]]),
#   'sig_z': array([[8.63386294, 8.6338932 , 8.63400153, ..., 8.94372951, 8.94361688,
#           8.94353086]]),
#   'turn': array([[  -1,    0,    1, ..., 5997, 5998, 5999]]),
#   'turn_duration': array([[1.89065933e-04, 9.43522611e+01, 9.40615690e+01, ...,
#           9.29417050e+01, 9.31009572e+01, 9.28295982e+01]]),
#   'turn_time': array([u'17:47:24', u'17:48:58', u'17:50:42', ..., u'17:11:43',
#          u'17:13:16', u'17:14:49'], dtype='<U8')},
#  '5 %': {'D_x': array([[3.08868431, 3.20732663, 3.35802474, ..., 3.22737546, 3.22705134,
#           3.22965297]]),
#   'D_y': array([[-0.0024603 , -0.00178954, -0.00099809, ..., -0.00125971,
#           -0.00102794,  0.00081584]]),
#   '__globals__': [],
#   '__header__': 'MATLAB 5.0 MAT-file Platform: posix, Created on: Sun Feb 23 11:19:09 2020',
#   '__version__': '1.0',
#   'alpha_x': array([[0.01239573, 0.04750815, 0.07824199, ..., 0.02855526, 0.02430455,
#           0.02551064]]),
#   'alpha_y': array([[ 0.08050199, -0.01192977,  0.03690659, ...,  0.06141863,
#            0.06218757,  0.06220204]]),
#   'beta_x': array([[21.7967186 , 21.9831373 , 21.31138497, ..., 21.07077016,
#           21.12673789, 21.22523547]]),
#   'beta_y': array([[12.20401092, 12.87595641, 13.73256313, ..., 13.08438236,
#           13.10859505, 13.08451731]]),
#   'bunchlength': array([[1.21601181e-07, 1.21601534e-07, 1.21603018e-07, ...,
#           1.25769137e-07, 1.25774214e-07, 1.25779657e-07]]),
#   'cumulative_time': array([[1.81913376e-04, 7.26680360e+01, 1.55069880e+02, ...,
#           2.58746333e+05, 2.58831669e+05, 2.58917128e+05]]),
#   'dpp_rms': array([[0.00122583, 0.00122583, 0.00122583, ..., 0.00119173, 0.00119168,
#           0.00119163]]),
#   'eff_alpha_x': array([[0.04882678, 0.04624683, 0.08300662, ..., 0.06660485, 0.06310361,
#           0.06346854]]),
#   'eff_alpha_y': array([[ 0.0805017 , -0.01192964,  0.03690658, ...,  0.06141833,
#            0.06218774,  0.06220188]]),
#   'eff_beta_x': array([[31.09477468, 31.91327237, 31.96779998, ..., 30.21372825,
#           30.26717827, 30.38382178]]),
#   'eff_beta_y': array([[12.20401754, 12.87596001, 13.73256429, ..., 13.0843817 ,
#           13.10859504, 13.08451645]]),
#   'eff_epsn_x': array([[9.05581356e-07, 9.21347994e-07, 9.53327613e-07, ...,
#           9.52646469e-07, 9.52166345e-07, 9.51471427e-07]]),
#   'eff_epsn_y': array([[6.33274098e-07, 6.33926322e-07, 6.36651078e-07, ...,
#           6.87595815e-07, 6.87437617e-07, 6.87412568e-07]]),
#   'eps_z': array([[1.23564943, 1.23565011, 1.23565124, ..., 1.24241186, 1.24240485,
#           1.24239721]]),
#   'epsn_x': array([[1.88203487e-06, 1.88253287e-06, 1.88423181e-06, ...,
#           1.97033566e-06, 1.97081773e-06, 1.97109874e-06]]),
#   'epsn_y': array([[1.87929219e-06, 1.88122833e-06, 1.88931469e-06, ...,
#           2.04049697e-06, 2.04002777e-06, 2.03995343e-06]]),
#   'gamma': array([[3.13154087, 3.13154087, 3.13154087, ..., 3.13154087, 3.13154087,
#           3.13154087]]),
#   'intensity': array([[3.25e+12, 3.25e+12, 3.25e+12, ..., 3.25e+12, 3.25e+12, 3.25e+12]]),
#   'kurtosis_dE': array([[-0.85350741, -0.85349533, -0.85348522, ..., -0.89358269,
#           -0.89336067, -0.89313567]]),
#   'kurtosis_dE_6sig': array([[-0.85350741, -0.85349533, -0.85348522, ..., -0.89358269,
#           -0.89336067, -0.89313567]]),
#   'kurtosis_x': array([[-0.22295559, -0.25694432, -0.28020165, ..., -0.27382244,
#           -0.2744422 , -0.27078859]]),
#   'kurtosis_x_6sig': array([[-0.22295559, -0.25694432, -0.28020165, ..., -0.27382244,
#           -0.2744422 , -0.27078859]]),
#   'kurtosis_xp': array([[ 0.00328029,  0.002772  ,  0.0003958 , ..., -0.12046574,
#           -0.13084583, -0.13063015]]),
#   'kurtosis_xp_6sig': array([[ 0.00328029,  0.002772  ,  0.0003958 , ..., -0.12046574,
#           -0.13084583, -0.13063015]]),
#   'kurtosis_y': array([[-0.01126053,  0.02410119, -0.06817129, ..., -0.25843563,
#           -0.24999686, -0.25574284]]),
#   'kurtosis_y_6sig': array([[-0.01126053,  0.02410119, -0.06817129, ..., -0.25843563,
#           -0.24999686, -0.25574284]]),
#   'kurtosis_yp': array([[ 0.00912397, -0.04048812,  0.07954291, ..., -0.12127523,
#           -0.12964959, -0.12068502]]),
#   'kurtosis_yp_6sig': array([[ 0.00912397, -0.04048812,  0.07954291, ..., -0.12127523,
#           -0.12964959, -0.12068502]]),
#   'kurtosis_z': array([[-0.86549986, -0.86547683, -0.8654501 , ..., -0.82860767,
#           -0.82891491, -0.829224  ]]),
#   'kurtosis_z_6sig': array([[-0.86549986, -0.86547683, -0.8654501 , ..., -0.82860767,
#           -0.82891491, -0.829224  ]]),
#   'max_dE': array([[0.00721456, 0.00721523, 0.00721869, ..., 0.00725782, 0.00725953,
#           0.00726148]]),
#   'max_x': array([[0.02201923, 0.02246228, 0.02543664, ..., 0.02308319, 0.02218138,
#           0.02330294]]),
#   'max_xp': array([[0.00082709, 0.00081778, 0.00077056, ..., 0.00078302, 0.00079067,
#           0.00073534]]),
#   'max_y': array([[0.0125477 , 0.01362239, 0.01348116, ..., 0.0142804 , 0.01530625,
#           0.0132025 ]]),
#   'max_yp': array([[0.00109365, 0.00099278, 0.00106841, ..., 0.00123753, 0.00106056,
#           0.00103043]]),
#   'max_z': array([[19.13518267, 19.14000071, 19.14432867, ..., 20.79699266,
#           20.79745677, 20.79737569]]),
#   'mean_dE': array([[-1.05021498e-05, -1.05918814e-05, -1.06807272e-05, ...,
#            4.10856430e-06,  4.10524538e-06,  4.10233540e-06]]),
#   'mean_x': array([[-1.39502064e-05, -2.13196413e-05, -3.05803716e-05, ...,
#            1.98063378e-05, -3.89723402e-06, -3.06833906e-05]]),
#   'mean_xp': array([[ 5.11651746e-09, -2.77551901e-07, -1.11474873e-07, ...,
#           -1.87795267e-07, -1.13586631e-06, -3.45786299e-07]]),
#   'mean_y': array([[-7.68637278e-07,  6.27907248e-06,  4.67124346e-07, ...,
#            3.04341543e-06, -6.44837135e-06, -2.85583312e-06]]),
#   'mean_yp': array([[ 5.20589484e-07,  7.23633051e-09, -5.18974916e-07, ...,
#           -5.41460852e-07, -1.97514241e-07,  5.53544565e-07]]),
#   'mean_z': array([[0.03543807, 0.03509083, 0.03474331, ..., 0.00546188, 0.00538165,
#           0.00530673]]),
#   'min_dE': array([[-0.00723587, -0.00723582, -0.00723966, ..., -0.00718994,
#           -0.0071932 , -0.0071964 ]]),
#   'min_x': array([[-0.02409084, -0.02176717, -0.02173147, ..., -0.02216731,
#           -0.02297019, -0.02180311]]),
#   'min_xp': array([[-0.00077466, -0.00076881, -0.00077381, ..., -0.00078973,
#           -0.00084666, -0.00081161]]),
#   'min_y': array([[-0.01156245, -0.01374578, -0.01372665, ..., -0.01368881,
#           -0.0125657 , -0.01373142]]),
#   'min_yp': array([[-0.00110186, -0.0009745 , -0.00111339, ..., -0.00106247,
#           -0.00116467, -0.00122972]]),
#   'min_z': array([[-19.13771317, -19.13939241, -19.13888299, ..., -20.40475866,
#           -20.3794568 , -20.35321484]]),
#   'mu_dE': array([[1.04620316e-05, 1.04620400e-05, 1.04618994e-05, ...,
#           9.88803676e-06, 9.88721192e-06, 9.88632498e-06]]),
#   'mu_x': array([[2.81588482e-05, 2.94032295e-05, 3.04757865e-05, ...,
#           2.87830015e-05, 2.88193885e-05, 2.89093383e-05]]),
#   'mu_xp': array([[2.91926962e-08, 2.89321175e-08, 3.00269689e-08, ...,
#           3.16701268e-08, 3.15839794e-08, 3.14412125e-08]]),
#   'mu_y': array([[7.72848820e-06, 8.16240997e-06, 8.74285186e-06, ...,
#           8.99676610e-06, 9.01134134e-06, 8.99446106e-06]]),
#   'mu_yp': array([[5.22269035e-08, 4.92403316e-08, 4.64238320e-08, ...,
#           5.27491163e-08, 5.26445551e-08, 5.27396042e-08]]),
#   'mu_z': array([[74.59102227, 74.59145525, 74.59327542, ..., 79.79196043,
#           79.79840274, 79.80530887]]),
#   'n_mp': array([[500000, 500000, 500000, ..., 500000, 500000, 500000]]),
#   'sig_dE': array([[0.00323451, 0.00323451, 0.00323449, ..., 0.00314452, 0.00314439,
#           0.00314425]]),
#   'sig_x': array([[0.00530649, 0.00542247, 0.00552049, ..., 0.00536498, 0.00536837,
#           0.00537674]]),
#   'sig_xp': array([[0.00017086, 0.00017009, 0.00017328, ..., 0.00017796, 0.00017772,
#           0.00017732]]),
#   'sig_y': array([[0.00278002, 0.00285699, 0.00295683, ..., 0.00299946, 0.00300189,
#           0.00299908]]),
#   'sig_yp': array([[0.00022853, 0.0002219 , 0.00021546, ..., 0.00022967, 0.00022944,
#           0.00022965]]),
#   'sig_z': array([[8.63660942, 8.63663449, 8.63673986, ..., 8.93263457, 8.93299517,
#           8.93338172]]),
#   'turn': array([[  -1,    0,    1, ..., 5997, 5998, 5999]]),
#   'turn_duration': array([[1.79052353e-04, 7.26677761e+01, 7.25433660e+01, ...,
#           8.55417080e+01, 8.53354361e+01, 8.54585690e+01]]),
#   'turn_time': array([u'17:53:48', u'17:55:01', u'17:56:23', ..., u'11:16:08',
#          u'11:17:34', u'11:18:59'], dtype='<U8')}}

# %%
dd['0 %'].keys()
# Out:
# ['eps_z',
#  'D_x',
#  'D_y',
#  'kurtosis_yp_6sig',
#  'kurtosis_yp',
#  'mu_yp',
#  'kurtosis_z_6sig',
#  'eff_beta_y',
#  'eff_beta_x',
#  'eff_alpha_y',
#  'kurtosis_y_6sig',
#  'epsn_y',
#  'epsn_x',
#  'beta_y',
#  'beta_x',
#  'dpp_rms',
#  'sig_yp',
#  'min_dE',
#  'turn_time',
#  'n_mp',
#  'min_xp',
#  'kurtosis_y',
#  'kurtosis_xp_6sig',
#  'alpha_x',
#  'alpha_y',
#  'bunchlength',
#  '__header__',
#  'sig_xp',
#  'kurtosis_dE_6sig',
#  'max_xp',
#  'intensity',
#  'min_yp',
#  'sig_dE',
#  'min_x',
#  'min_y',
#  'mu_y',
#  'mu_x',
#  'cumulative_time',
#  'mean_yp',
#  'kurtosis_xp',
#  'eff_epsn_y',
#  'eff_epsn_x',
#  'mean_x',
#  'mean_y',
#  'mean_z',
#  'kurtosis_x_6sig',
#  '__version__',
#  'max_z',
#  'mu_dE',
#  'max_x',
#  'max_y',
#  'mean_dE',
#  'sig_z',
#  'sig_y',
#  'sig_x',
#  'max_yp',
#  'kurtosis_z',
#  'eff_alpha_x',
#  'kurtosis_x',
#  'mu_xp',
#  'turn_duration',
#  'mu_z',
#  'mean_xp',
#  'min_z',
#  'kurtosis_dE',
#  '__globals__',
#  'turn',
#  'max_dE',
#  'gamma']

# %%
parameter = 'sig_x'
multi = 1E3

fig1 = plt.figure(facecolor='w', edgecolor='k')
ax1 = fig1.add_subplot(111)

tit = main_label + ' ' + sc + ' ' + parameter
ax1.set_title(tit);

ax1.set_ylabel(r'$\sigma_x$ [mm]');
ax1.set_xlabel('Turn [-]');

colors = cm.rainbow(np.linspace(0, 1, len(dd.keys())))
c_it = int(0)

for key, value in sorted(dd.iteritems()):
    ax1.plot(dd[key]['turn'][0], dd[key][parameter][0]*multi, label=key, color=colors[c_it]);
    c_it = c_it + 1;
        
ax1.legend(loc=3, title=legend_label)
ax1.grid(lw=0.5, ls=':');
ax1.set_xlim(-1,turn_tot)

fig1.tight_layout()

savename = save_folder + '/'+ main_label + '_' + parameter + '.png'
plt.savefig(savename, dpi = 800);

# %%
parameter = 'sig_x'
multi = 1E3

fig1 = plt.figure(facecolor='w', edgecolor='k')
ax1 = fig1.add_subplot(111)
ax2 = ax1.twinx()

tit = main_label + ' ' + sc + ' ' + parameter
ax1.set_title(tit);

ax1.set_ylabel(r'$\sigma_x$ [mm]');
ax2.set_ylabel(r'$\left(\frac{\delta p}{p_0}\right)_{RMS}$ [1E-3]');
ax1.set_xlabel('Turn [-]');

colors = cm.rainbow(np.linspace(0, 1, len(dd.keys())))
c_it = int(0)

for key, value in sorted(dd.iteritems()):
    ax1.plot(dd[key]['turn'][0], dd[key][parameter][0]*multi, label=key, color=colors[c_it], ls='-');
    ax2.plot(dd[key]['turn'][0], dd[key]['dpp_rms'][0]*multi, color=colors[c_it], ls=':');
    c_it = c_it + 1;
    

        
ax1.legend(loc=4, title=legend_label)
ax1.grid(lw=0.5, ls=':');
#ax1.set_xlim(-1,3000)
ax2.set_ylim(1.0, 1.25)
ax1.set_ylim(5.0, 6.0)

custom_lines = [Line2D([0], [0], color='k', lw=4, linestyle='-'),
                Line2D([0], [0], color='k', lw=4, linestyle=':'),
                Line2D([0], [0], color='b', lw=4, linestyle='--')]

ax2.legend(custom_lines, [r'$\left(\frac{\delta p}{p_0}\right)_{RMS}$',r'$\sigma_x$', r'$\frac{1}{Q_s}$'], loc=1)

ax1.vlines(500, 5, 6, colors='b', linestyles='solid', label='', lw=0.5, linestyle='--')
ax1.vlines(500+520, 5, 6, colors='b', linestyles='solid', label='', lw=0.5, linestyle='--')
ax1.vlines(500+520+520, 5, 6, colors='b', linestyles='solid', label='', lw=0.5, linestyle='--')

fig1.tight_layout()

savename = save_folder + '/'+ main_label + '_Sigma_cf_RF.png'
plt.savefig(savename, dpi = 800);

# %%
parameter = 'sig_y'
multi = 1E3

fig1 = plt.figure(facecolor='w', edgecolor='k')
ax1 = fig1.add_subplot(111)

tit = main_label + ' ' + sc + ' ' + parameter
ax1.set_title(tit);

ax1.set_ylabel(r'$\sigma_y$ [mm]');
ax1.set_xlabel('Turn [-]');

colors = cm.rainbow(np.linspace(0, 1, len(dd.keys())))
c_it = int(0)

for key, value in sorted(dd.iteritems()):
    ax1.plot(dd[key]['turn'][0], dd[key][parameter][0]*multi, label=key, color=colors[c_it]);
    c_it = c_it + 1;
        
ax1.legend(loc=3, title=legend_label)
ax1.grid(lw=0.5, ls=':');
ax1.set_xlim(-1,turn_tot)

fig1.tight_layout()

savename = save_folder + '/'+ main_label + '_' + parameter + '.png'
plt.savefig(savename, dpi = 800);

# %%
parameter = 'dpp_rms'
multi = 1E3

fig1 = plt.figure(facecolor='w', edgecolor='k')
ax1 = fig1.add_subplot(111)

tit = main_label + ' ' + sc + ' ' + parameter
ax1.set_title(tit);

ax1.set_ylabel(r'$\left(\frac{\delta p}{p_0}\right)_{RMS}$ [1E-3]');
ax1.set_xlabel('Turn [-]');

colors = cm.rainbow(np.linspace(0, 1, len(dd.keys())))
c_it = int(0)

for key, value in sorted(dd.iteritems()):
    ax1.plot(dd[key]['turn'][0], dd[key][parameter][0]*multi, label=key, color=colors[c_it]);
    c_it = c_it + 1;
        
ax1.legend(loc=3, title=legend_label)
ax1.grid(lw=0.5, ls=':');
ax1.set_xlim(-1,turn_tot)

#ax1.set_ylim(1.63, 1.71)

fig1.tight_layout()

savename = save_folder + '/'+ main_label + '_' + parameter + '.png'
plt.savefig(savename, dpi = 800);

# %%
parameter = 'sig_x'
multi = 1E3

fig1 = plt.figure(facecolor='w', edgecolor='k')
ax1 = fig1.add_subplot(111)
ax2 = ax1.twinx()

tit = main_label + ' ' + sc + ' ' + parameter
ax1.set_title(tit);

ax1.set_ylabel(r'$\sigma_x$ [mm]');
ax2.set_ylabel(r'$\left(\frac{\delta p}{p_0}\right)_{RMS}$ [1E-3]');
ax1.set_xlabel('Turn [-]');

colors = cm.rainbow(np.linspace(0, 1, len(dd.keys())))
c_it = int(0)

for key, value in sorted(dd.iteritems()):
    ax1.plot(dd[key]['turn'][0], dd[key][parameter][0]*multi, label=key, color=colors[c_it], ls='-');
    ax2.plot(dd[key]['turn'][0], dd[key]['dpp_rms'][0]*multi, color=colors[c_it], ls=':');
    c_it = c_it + 1;
    

        
ax1.legend(loc=3, title=legend_label, fontsize='small')
ax1.grid(lw=0.5, ls=':');
ax1.set_xlim(-1,3200)
ax2.set_ylim(1.52, 1.8)
ax1.set_ylim(6.4, 7.4)

q_s = 1.85E-3
f_s = 1/q_s
peak_turn = 740
ax1.vlines(peak_turn-f_s, 6, 10, colors='k', linestyles='solid', label='', lw=0.5, linestyle='--')
ax1.vlines(peak_turn, 6, 10, colors='k', linestyles='solid', label='', lw=0.5, linestyle='--')
ax1.vlines(peak_turn+f_s, 6, 10, colors='k', linestyles='solid', label='', lw=0.5, linestyle='--')
ax1.vlines(peak_turn+f_s+f_s, 6, 10, colors='k', linestyles='solid', label='', lw=0.5, linestyle='--')
ax1.vlines(peak_turn+f_s+f_s+f_s, 6, 10, colors='k', linestyles='solid', label='', lw=0.5, linestyle='--')
ax1.vlines(peak_turn+f_s+f_s+f_s+f_s, 6, 10, colors='k', linestyles='solid', label='', lw=0.5, linestyle='--')

custom_lines = [Line2D([0], [0], color='r', lw=4, linestyle='-'),
                Line2D([0], [0], color='r', lw=4, linestyle=':'),
                Line2D([0], [0], color='k', lw=4, linestyle='--')]

lab3 = r'$\frac{1}{Q_s}\approx$ ' + str(round_sig(f_s,3)) + ' turns'
ax2.legend(custom_lines, [r'$\sigma_x$', r'$\left(\frac{\delta p}{p_0}\right)_{RMS}$',lab3], loc=1, fontsize='small')

fig1.tight_layout()

savename = save_folder + '/sig_x_synch_period.png'
plt.savefig(savename, dpi = 800);

print 'Synchroton period looks like ', round_sig(f_s,3), ' turns'
# Out:
# Synchroton period looks like  541.0  turns

# %%
for key, value in sorted(dd.iteritems()):
    print '\n', key, ' bunch length deviation +/- ', round_sig((np.max(dd[key]['bunchlength'][0]*1E9) - np.min(dd[key]['bunchlength'][0]*1E9))/2,3), 'ns'
# Out:
# 0 %  bunch length deviation +/-  6.65 ns
#
# 10 %  bunch length deviation +/-  6.5 ns
#
# 5 %  bunch length deviation +/-  6.62 ns

# %%
parameter = 'bunchlength'
multi = 1E9

fig1 = plt.figure(facecolor='w', edgecolor='k')
ax1 = fig1.add_subplot(111)

tit = main_label + ' ' + sc + ' ' + parameter
ax1.set_title(tit);

ax1.set_ylabel(r'$B_l$ [ns]');
ax1.set_xlabel('Turn [-]');

colors = cm.rainbow(np.linspace(0, 1, len(dd.keys())))
c_it = int(0)

for key, value in sorted(dd.iteritems()):
    ax1.plot(dd[key]['turn'][0], dd[key][parameter][0]*multi, label=key, color=colors[c_it]);
    c_it = c_it + 1;
        
ax1.legend(loc=3, title=legend_label)
ax1.grid(lw=0.5, ls=':');
ax1.set_xlim(-1,turn_tot)

fig1.tight_layout()

savename = save_folder + '/'+ main_label + '_' + parameter + '.png'
plt.savefig(savename, dpi = 800);

# %%
parameter = 'beta_x'
multi = 1

fig1 = plt.figure(facecolor='w', edgecolor='k')
ax1 = fig1.add_subplot(111)

tit = main_label + ' ' + sc + ' ' + parameter
ax1.set_title(tit);

ax1.set_ylabel(r'$\beta_{x}$ [m]');
ax1.set_xlabel('Turn [-]');

colors = cm.rainbow(np.linspace(0, 1, len(dd.keys())))
c_it = int(0)

for key, value in sorted(dd.iteritems()):
    ax1.plot(dd[key]['turn'][0], dd[key][parameter][0]*multi, label=key, color=colors[c_it]);
    c_it = c_it + 1;
        
ax1.legend(loc=3, title=legend_label)
ax1.grid(lw=0.5, ls=':');
#ax1.set_xlim(-1,turn_tot)

fig1.tight_layout()

savename = save_folder + '/'+ main_label + '_' + parameter + '.png'
plt.savefig(savename, dpi = 800);

# %%
parameter = 'beta_y'
multi = 1

fig1 = plt.figure(facecolor='w', edgecolor='k')
ax1 = fig1.add_subplot(111)

tit = main_label + ' ' + sc + ' ' + parameter
ax1.set_title(tit);

ax1.set_ylabel(r'$\beta_{y}$ [m]');
ax1.set_xlabel('Turn [-]');

colors = cm.rainbow(np.linspace(0, 1, len(dd.keys())))
c_it = int(0)

for key, value in sorted(dd.iteritems()):
    ax1.plot(dd[key]['turn'][0], dd[key][parameter][0]*multi, label=key, color=colors[c_it]);
    c_it = c_it + 1;
        
ax1.legend(loc=3, title=legend_label)
ax1.grid(lw=0.5, ls=':');
#ax1.set_xlim(-1,turn_tot)

fig1.tight_layout()

savename = save_folder + '/'+ main_label + '_' + parameter + '.png'
plt.savefig(savename, dpi = 800);

# %%
parameter = 'epsn_x'
multi = 1E6

fig1 = plt.figure(facecolor='w', edgecolor='k')
ax1 = fig1.add_subplot(111)

tit = main_label + ' ' + sc + ' ' + parameter
ax1.set_title(tit);

ax1.set_ylabel(r'$\epsilon_{x_{RMS}}$ [mm mrad]');
ax1.set_xlabel('Turn [-]');

colors = cm.rainbow(np.linspace(0, 1, len(dd.keys())))
c_it = int(0)

for key, value in sorted(dd.iteritems()):
    ax1.plot(dd[key]['turn'][0], dd[key][parameter][0]*multi, label=key, color=colors[c_it]);
    c_it = c_it + 1;
        
ax1.legend(loc=2, title=legend_label)
ax1.grid(lw=0.5, ls=':');
#ax1.set_xlim(-1,turn_tot)

fig1.tight_layout()

savename = save_folder + '/'+ main_label + '_' + parameter + '.png'
plt.savefig(savename, dpi = 800);

# %%
parameter = 'epsn_y'
multi = 1E6

fig1 = plt.figure(facecolor='w', edgecolor='k')
ax1 = fig1.add_subplot(111)

tit = main_label + ' ' + sc + ' ' + parameter
ax1.set_title(tit);

ax1.set_ylabel(r'$\epsilon_{y_{RMS}}$ [mm mrad]');
ax1.set_xlabel('Turn [-]');

colors = cm.rainbow(np.linspace(0, 1, len(dd.keys())))
c_it = int(0)

for key, value in sorted(dd.iteritems()):
    ax1.plot(dd[key]['turn'][0], dd[key][parameter][0]*multi, label=key, color=colors[c_it]);
    c_it = c_it + 1;
        
ax1.legend(loc=2, title=legend_label)
ax1.grid(lw=0.5, ls=':');
ax1.set_ylim(1.85, 2.25)

fig1.tight_layout()

savename = save_folder + '/'+ main_label + '_' + parameter + '.png'
plt.savefig(savename, dpi = 800);

# %%
print 'Vertical Emittance growth = ', round_sig(100*((1/(dd[41.2]['epsn_y'][0][0]/dd[41.2]['epsn_y'][0][-1]))-1),3), '%'
# Out:
# Vertical Emittance growth =
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-0fd28c156da0> in <module>()
# ----> 1 print 'Vertical Emittance growth = ', round_sig(100*((1/(dd[41.2]['epsn_y'][0][0]/dd[41.2]['epsn_y'][0][-1]))-1),3), '%'
#
# KeyError: 41.2

# %%
parameter1 = 'epsn_x'
parameter2 = 'epsn_y'
multi1 = 1E6
multi2 = 1E6

fig1 = plt.figure(facecolor='w', edgecolor='k')
ax1 = fig1.add_subplot(111)

tit = main_label + ' ' + sc + ' average emittance'
ax1.set_title(tit);

ax1.set_ylabel(r'$\frac{\epsilon_{x_{RMS}} + \epsilon_{y_{RMS}}}{2}$ [mm mrad]');
ax1.set_xlabel('Turn [-]');

colors = cm.rainbow(np.linspace(0, 1, len(dd.keys())))
c_it = int(0)


for key, value in sorted(dd.iteritems()):
        ax1.plot(dd[key]['turn'][0], (dd[key][parameter1][0]*multi1 + dd[key][parameter2][0]*multi2)/2, label=key, color=colors[c_it]);
        c_it = c_it + 1;
        
ax1.legend(loc=2, title=legend_label);
ax1.grid(lw=0.5, ls=':');
#ax1.set_xlim(-1,turn_tot);

fig1.tight_layout()
savename = save_folder + '/'+ main_label + '_epsn_av.png'
plt.savefig(savename, dpi = 800);

# %%
parameter = 'D_x'
multi = 1

fig1 = plt.figure(facecolor='w', edgecolor='k')
ax1 = fig1.add_subplot(111)

tit = main_label + ' ' + sc + ' ' + parameter
ax1.set_title(tit);

ax1.set_ylabel(r'$D_{x}$ [m]');
ax1.set_xlabel('Turn [-]');

colors = cm.rainbow(np.linspace(0, 1, len(dd.keys())))
c_it = int(0)

for key, value in sorted(dd.iteritems()):
    ax1.plot(dd[key]['turn'][0], dd[key][parameter][0]*multi, label=key, color=colors[c_it]);
    c_it = c_it + 1;
        
ax1.legend(loc=3)
ax1.grid(lw=0.5, ls=':');
#ax1.set_xlim(-1,turn_tot)

fig1.tight_layout()

savename = save_folder + '/'+ main_label + '_' + parameter + '.png'
plt.savefig(savename, dpi = 800);

# %%
parameter = 'D_y'
multi = 1

fig1 = plt.figure(facecolor='w', edgecolor='k')
ax1 = fig1.add_subplot(111)

tit = main_label + ' ' + sc + ' ' + parameter
ax1.set_title(tit);

ax1.set_ylabel(r'$D_{y}$ [m]');
ax1.set_xlabel('Turn [-]');

colors = cm.rainbow(np.linspace(0, 1, len(dd.keys())))
c_it = int(0)

for key, value in sorted(dd.iteritems()):
    ax1.plot(dd[key]['turn'][0], dd[key][parameter][0]*multi, label=key, color=colors[c_it]);
    c_it = c_it + 1;
        
ax1.legend(loc=3)
ax1.grid(lw=0.5, ls=':');
#ax1.set_xlim(-1,turn_tot)

fig1.tight_layout()

savename = save_folder + '/'+ main_label + '_' + parameter + '.png'
plt.savefig(savename, dpi = 800);

# %%
dd['2021 Standard']['epsn_y'][0][1199]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-a8b3a23621f6> in <module>()
# ----> 1 dd['2021 Standard']['epsn_y'][0][1199]
#
# KeyError: '2021 Standard'

# %%
ep_0_21 = (dd['2021 Standard']['epsn_x'][0][0] + dd['2021 Standard']['epsn_y'][0][0])/2
ep_f_21 = (dd['2021 Standard']['epsn_x'][0][999] + dd['2021 Standard']['epsn_y'][0][999])/2
print '2021: epsn_av_0 = ', ep_0_21
print '2021: epsn_av_1000 = ', ep_f_21
print '2021: average emttance growth in 1000 turns = ', round_sig(((ep_f_21/ep_0_21)*100-100),3), '%'

# %%
ep_0_22 = (dd['2022 Standard']['epsn_x'][0][0] + dd['2022 Standard']['epsn_y'][0][0])/2
ep_f_22 = (dd['2022 Standard']['epsn_x'][0][999] + dd['2022 Standard']['epsn_y'][0][999])/2

print '2022: average emttance growth in 1000 turns = ', round_sig(((ep_f_22/ep_0_22)*100-100),3), '%'

# %%
ep_0_23 = (dd['2023 Standard']['epsn_x'][0][0] + dd['2023 Standard']['epsn_y'][0][0])/2
ep_f_23 = (dd['2023 Standard']['epsn_x'][0][999] + dd['2023 Standard']['epsn_y'][0][999])/2

print '2023: average emttance growth in 1000 turns = ', round_sig(((ep_f_23/ep_0_23)*100-100),3), '%'
