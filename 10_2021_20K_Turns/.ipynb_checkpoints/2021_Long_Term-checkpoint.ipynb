# %% [markdown]
# # 10: LIU Ramp-Up: 2021 Long Term Tracking: SC

# %%
import imageio
import pickle
import pandas as pd
import numpy as np
import PyNAFF as pnf
import scipy.io as sio 
import matplotlib.cm as cm
from math import log10, floor
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from matplotlib.patches import Patch
from scipy.optimize import curve_fit

# %% [markdown]
# ### Figure parameters

# %%
plt.rcParams['figure.figsize'] = [5.0, 4.5]
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300

plt.rcParams['axes.titlesize'] = 14
plt.rcParams['axes.labelsize'] = 14

plt.rcParams['xtick.labelsize'] = 10
plt.rcParams['ytick.labelsize'] = 10

plt.rcParams['font.size'] = 10
plt.rcParams['legend.fontsize'] = 10

plt.rcParams['lines.linewidth'] = 1.5
plt.rcParams['lines.markersize'] = 5

# %% [markdown]
# ### Function Declarations

# %%
def harmonic_fn(x, a, b, c, d):
    return a + b*np.cos(c + 2*np.pi*d*x)

def quadratic(x, a, m, c):
    return a*x**2 + x*m + c

def quadratic(x, a, m, c):
    return a*x**2 + x*m + c

def Md_fit(x, a, b, c, d):
        return a + b*np.cos(c*x+d)
    
def Md_ramp_fit(x, a, b, c, d):
    return a + b*(x-1)*np.cos(c*(x-1)+d)

def round_sig(x, sig=4):
    return round(x, sig-int(floor(log10(abs(x))))-1)

# %%
def add_input_file(dd, filename, label):
	f = filename
	p = dict()
	sio.loadmat(f, mdict=p)
	dd[label] = p	
	print '\tAdded output data from ', filename, '\t dictionary key: ', label
	return dd

# %% [markdown]
# ## Import Data

# %%
#Horizontal Scan No Space Charge

# Create dd dictionary
dd = dict()


dd = add_input_file(dd, '00/output/output.mat', '0 %')
dd = add_input_file(dd, '05/output/output.mat', '5 %')
dd = add_input_file(dd, '10/output/output.mat', '10 %')
# Out:
# 	Added output data from  00/output/output.mat 	 dictionary key:  0 %
# 	Added output data from  05/output/output.mat 	 dictionary key:  5 %
# 	Added output data from  10/output/output.mat 	 dictionary key:  10 %

# %% [markdown]
# ### Plot Parameters

# %%
save_folder = 'Plots/'

sc = 'SbS'
legend_label = r'$\frac{\Delta \beta}{\beta_0}$' # r'$\frac{\delta p}{p_0}$'
main_label = 'PS_LIU_2021'
main_label2 = main_label + '_zoom'
scaled_label = main_label + '_scaled'
turn_tot = 9000
zoom_turns = 50
betagamma = 3.13154090774 * 0.947643035549 # 2GeV
#betagamma = 2.492104532 * 0.9159915293879255 # 1.4GeV

# %%
dd
# Out:
# {'0 %': {'D_x': array([[3.12705879, 3.22093994, 3.36710246, ..., 3.24339112, 3.25992496,
#           3.27814083]]),
#   'D_y': array([[-2.69596114e-03, -5.10780214e-03, -5.60179430e-03, ...,
#           -9.13583210e-05, -5.40216904e-04, -9.00364081e-04]]),
#   '__globals__': [],
#   '__header__': 'MATLAB 5.0 MAT-file Platform: posix, Created on: Fri Feb 28 13:39:26 2020',
#   '__version__': '1.0',
#   'alpha_x': array([[0.03021035, 0.02838221, 0.03798833, ..., 0.02382509, 0.02520277,
#           0.02562105]]),
#   'alpha_y': array([[0.05180475, 0.01312305, 0.0566337 , ..., 0.05702533, 0.05945129,
#           0.05699862]]),
#   'beta_x': array([[22.46924304, 22.51855021, 22.45839209, ..., 22.42248075,
#           22.42899776, 22.46143911]]),
#   'beta_y': array([[11.69305703, 12.31045643, 12.66421372, ..., 12.23918446,
#           12.19610727, 12.26321477]]),
#   'bunchlength': array([[1.21517983e-07, 1.21518581e-07, 1.21520308e-07, ...,
#           1.26853680e-07, 1.26864604e-07, 1.26875833e-07]]),
#   'cumulative_time': array([[1.96218491e-04, 9.27420220e+01, 1.95575202e+02, ...,
#           2.74794372e+05, 2.74885671e+05, 2.74976714e+05]]),
#   'dpp_rms': array([[0.00122504, 0.00122504, 0.00122503, ..., 0.00118058, 0.00118047,
#           0.00118037]]),
#   'eff_alpha_x': array([[ 0.02650685, -0.00406951,  0.01352371, ...,  0.02153246,
#            0.01987087,  0.02254435]]),
#   'eff_alpha_y': array([[0.05180265, 0.01312133, 0.05663519, ..., 0.05702533, 0.05945132,
#           0.05699878]]),
#   'eff_beta_x': array([[32.03279251, 32.55193293, 33.27096229, ..., 31.66692563,
#           31.75024758, 31.87118907]]),
#   'eff_beta_y': array([[11.69304869, 12.31048353, 12.6642489 , ..., 12.23918381,
#           12.19610745, 12.26321426]]),
#   'eff_epsn_x': array([[9.01620839e-07, 9.15658936e-07, 9.38212993e-07, ...,
#           9.28400378e-07, 9.30807909e-07, 9.33187722e-07]]),
#   'eff_epsn_y': array([[6.33515600e-07, 6.33808274e-07, 6.34758078e-07, ...,
#           6.92127548e-07, 6.92021809e-07, 6.91938153e-07]]),
#   'eps_z': array([[1.23400377, 1.23400308, 1.2340031 , ..., 1.24128202, 1.24127487,
#           1.24126827]]),
#   'epsn_x': array([[1.87631220e-06, 1.87625461e-06, 1.87652551e-06, ...,
#           1.95052645e-06, 1.95082197e-06, 1.95132439e-06]]),
#   'epsn_y': array([[1.88000595e-06, 1.88087330e-06, 1.88369141e-06, ...,
#           2.05394576e-06, 2.05363201e-06, 2.05338347e-06]]),
#   'gamma': array([[3.13154087, 3.13154087, 3.13154087, ..., 3.13154087, 3.13154087,
#           3.13154087]]),
#   'intensity': array([[3.25e+12, 3.25e+12, 3.25e+12, ..., 3.25e+12, 3.25e+12, 3.25e+12]]),
#   'kurtosis_dE': array([[-0.85253897, -0.8525132 , -0.85248812, ..., -0.8788343 ,
#           -0.87865916, -0.87848464]]),
#   'kurtosis_dE_6sig': array([[-0.85253897, -0.8525132 , -0.85248812, ..., -0.8788343 ,
#           -0.87865916, -0.87848464]]),
#   'kurtosis_x': array([[-0.21177346, -0.23856309, -0.27325998, ..., -0.25903076,
#           -0.25318949, -0.26729597]]),
#   'kurtosis_x_6sig': array([[-0.21177346, -0.23856309, -0.27325998, ..., -0.25903076,
#           -0.25318949, -0.26729597]]),
#   'kurtosis_xp': array([[ 0.00107818, -0.01399547, -0.01240947, ..., -0.07119465,
#           -0.07626202, -0.0642844 ]]),
#   'kurtosis_xp_6sig': array([[ 0.00107818, -0.01399547, -0.01240947, ..., -0.07119465,
#           -0.07626202, -0.0642844 ]]),
#   'kurtosis_y': array([[-0.01515008, -0.00418848, -0.05630052, ..., -0.22248512,
#           -0.22955161, -0.23422128]]),
#   'kurtosis_y_6sig': array([[-0.01515008, -0.00418848, -0.05630052, ..., -0.2438623 ,
#           -0.22955161, -0.25345242]]),
#   'kurtosis_yp': array([[ 0.00310356, -0.01602377,  0.0560175 , ..., -0.18078703,
#           -0.15783686, -0.1678407 ]]),
#   'kurtosis_yp_6sig': array([[ 0.00310356, -0.01602377,  0.0560175 , ..., -0.18078703,
#           -0.18351613, -0.1678407 ]]),
#   'kurtosis_z': array([[-0.86800699, -0.86802501, -0.86803829, ..., -0.83969138,
#           -0.83992656, -0.84016509]]),
#   'kurtosis_z_6sig': array([[-0.86800699, -0.86802501, -0.86803829, ..., -0.83969138,
#           -0.83992656, -0.84016509]]),
#   'max_dE': array([[0.00721343, 0.00721405, 0.00721401, ..., 0.0071117 , 0.00710901,
#           0.00710619]]),
#   'max_x': array([[0.02418259, 0.02260416, 0.02560935, ..., 0.02219511, 0.0228578 ,
#           0.02276045]]),
#   'max_xp': array([[0.00074136, 0.00077749, 0.00081511, ..., 0.00084096, 0.0007466 ,
#           0.00077405]]),
#   'max_y': array([[0.0128607 , 0.01248106, 0.01274613, ..., 0.02998741, 0.01309153,
#           0.01241755]]),
#   'max_yp': array([[0.00102612, 0.00100105, 0.0011027 , ..., 0.00113348, 0.00110663,
#           0.00110865]]),
#   'max_z': array([[19.12787006, 19.11960889, 19.1144074 , ..., 21.19413616,
#           21.20160608, 21.20895919]]),
#   'mean_dE': array([[-1.31909773e-05, -1.31906873e-05, -1.31891277e-05, ...,
#            1.59506220e-05,  1.58199226e-05,  1.56888648e-05]]),
#   'mean_x': array([[-2.22410046e-05, -2.35451609e-05, -2.75552102e-05, ...,
#            1.61291805e-07, -9.53954961e-06,  7.29901582e-06]]),
#   'mean_xp': array([[ 1.17980572e-08, -1.20865299e-07, -1.66446485e-07, ...,
#           -7.17092105e-07,  1.92023425e-07,  7.98996890e-07]]),
#   'mean_y': array([[ 5.79969617e-07, -1.36216842e-06, -8.69188483e-07, ...,
#           -1.55393155e-06, -6.63916573e-07,  1.49820190e-06]]),
#   'mean_yp': array([[-1.19940569e-07, -5.75103653e-08,  1.10075068e-07, ...,
#           -4.49727392e-08,  1.34398809e-07,  5.31064706e-08]]),
#   'mean_z': array([[0.00186299, 0.00146945, 0.00107622, ..., 0.05552033, 0.05565823,
#           0.05579291]]),
#   'min_dE': array([[-0.00724008, -0.00724315, -0.00724763, ..., -0.0069887 ,
#           -0.00700143, -0.00701402]]),
#   'min_x': array([[-0.0230374 , -0.02424465, -0.02234171, ..., -0.02329477,
#           -0.02229086, -0.02282954]]),
#   'min_xp': array([[-0.00075847, -0.00077551, -0.00076636, ..., -0.00073952,
#           -0.0007803 , -0.00079475]]),
#   'min_y': array([[-0.01204977, -0.01294162, -0.01221284, ..., -0.01313564,
#           -0.01350746, -0.02924879]]),
#   'min_yp': array([[-0.00111678, -0.00102826, -0.00109709, ..., -0.00119395,
#           -0.00257161, -0.00106981]]),
#   'min_z': array([[-19.13138358, -19.12550935, -19.13090525, ..., -21.37734635,
#           -21.37444982, -21.37088891]]),
#   'mu_dE': array([[1.04484862e-05, 1.04484389e-05, 1.04482477e-05, ...,
#           9.70378224e-06, 9.70208865e-06, 9.70035794e-06]]),
#   'mu_x': array([[2.88814333e-05, 2.98064683e-05, 3.12152491e-05, ...,
#           2.93995857e-05, 2.95533816e-05, 2.97418023e-05]]),
#   'mu_xp': array([[2.81665837e-08, 2.81296383e-08, 2.82043115e-08, ...,
#           2.93312600e-08, 2.93281316e-08, 2.92948597e-08]]),
#   'mu_y': array([[7.40772875e-06, 7.80248632e-06, 8.03873429e-06, ...,
#           8.47107628e-06, 8.43997233e-06, 8.48538582e-06]]),
#   'mu_yp': array([[5.43242113e-08, 5.14941102e-08, 5.02828157e-08, ...,
#           5.67340340e-08, 5.69417525e-08, 5.66071952e-08]]),
#   'mu_z': array([[74.48898823, 74.48972189, 74.49183843, ..., 81.17403131,
#           81.18801196, 81.20238458]]),
#   'n_mp': array([[500000, 500000, 500000, ..., 500000, 500000, 500000]]),
#   'sig_dE': array([[0.00323241, 0.0032324 , 0.00323237, ..., 0.00311509, 0.00311482,
#           0.00311454]]),
#   'sig_x': array([[0.00537414, 0.00545953, 0.00558706, ..., 0.00542214, 0.0054363 ,
#           0.0054536 ]]),
#   'sig_xp': array([[0.00016783, 0.00016772, 0.00016794, ..., 0.00017126, 0.00017125,
#           0.00017116]]),
#   'sig_y': array([[0.00272171, 0.00279329, 0.00283527, ..., 0.00291051, 0.00290516,
#           0.00291297]]),
#   'sig_yp': array([[0.00023308, 0.00022692, 0.00022424, ..., 0.00023819, 0.00023862,
#           0.00023792]]),
#   'sig_z': array([[8.63070033, 8.63074284, 8.63086545, ..., 9.00966322, 9.01043905,
#           9.01123657]]),
#   'turn': array([[  -1,    0,    1, ..., 8997, 8998, 8999]]),
#   'turn_duration': array([[1.92880630e-04, 9.27417681e+01, 9.27838612e+01, ...,
#           9.10580111e+01, 9.12987411e+01, 9.10429921e+01]]),
#   'turn_time': array([u'17:53:06', u'17:54:39', u'17:56:22', ..., u'13:36:14',
#          u'13:37:45', u'13:39:16'], dtype='<U8')},
#  '10 %': {'D_x': array([[3.05557172, 3.19165456, 3.34148667, ..., 3.19034585, 3.18529183,
#           3.19105369]]),
#   'D_y': array([[-0.00261388,  0.00081067,  0.00242945, ...,  0.00036982,
#            0.00548413,  0.00818037]]),
#   '__globals__': [],
#   '__header__': 'MATLAB 5.0 MAT-file Platform: posix, Created on: Fri Feb 28 14:57:44 2020',
#   '__version__': '1.0',
#   'alpha_x': array([[0.000505  , 0.07070148, 0.11662978, ..., 0.0278784 , 0.02750194,
#           0.02663143]]),
#   'alpha_y': array([[ 0.11433912, -0.03404823,  0.02351023, ...,  0.06590546,
#            0.07021226,  0.06214957]]),
#   'beta_x': array([[21.17939267, 21.27882302, 20.15272672, ..., 19.95986171,
#           19.96776322, 20.00780586]]),
#   'beta_y': array([[12.80116059, 13.3799197 , 14.87261567, ..., 13.91089571,
#           13.85236216, 13.88034243]]),
#   'bunchlength': array([[1.21562511e-07, 1.21562937e-07, 1.21564463e-07, ...,
#           1.26860031e-07, 1.26864313e-07, 1.26868839e-07]]),
#   'cumulative_time': array([[1.91926956e-04, 9.43525128e+01, 1.98427783e+02, ...,
#           2.79480725e+05, 2.79573684e+05, 2.79666656e+05]]),
#   'dpp_rms': array([[0.00122349, 0.00122348, 0.00122347, ..., 0.00117913, 0.00117909,
#           0.00117904]]),
#   'eff_alpha_x': array([[0.07859812, 0.10432176, 0.15356041, ..., 0.10881962, 0.10659904,
#           0.10413806]]),
#   'eff_alpha_y': array([[ 0.11434129, -0.03404878,  0.02350959, ...,  0.06590489,
#            0.07020799,  0.06215063]]),
#   'eff_beta_x': array([[30.17043525, 31.05496743, 30.58127047, ..., 28.40807143,
#           28.39642086, 28.4673671 ]]),
#   'eff_beta_y': array([[12.80114057, 13.37989905, 14.87261922, ..., 13.9108503 ,
#           13.85236338, 13.88040933]]),
#   'eff_epsn_x': array([[9.08164871e-07, 9.25570164e-07, 9.65741922e-07, ...,
#           9.79409722e-07, 9.78359301e-07, 9.78610249e-07]]),
#   'eff_epsn_y': array([[6.33976821e-07, 6.35166500e-07, 6.40397395e-07, ...,
#           6.90933227e-07, 6.91071335e-07, 6.91011533e-07]]),
#   'eps_z': array([[1.2328908 , 1.23288935, 1.2328883 , ..., 1.23993909, 1.23993547,
#           1.23993207]]),
#   'epsn_x': array([[1.88088455e-06, 1.88203733e-06, 1.88781504e-06, ...,
#           2.03269669e-06, 2.03256724e-06, 2.03243121e-06]]),
#   'epsn_y': array([[1.88137346e-06, 1.88490611e-06, 1.90043105e-06, ...,
#           2.05039489e-06, 2.05080270e-06, 2.05062400e-06]]),
#   'gamma': array([[3.13154087, 3.13154087, 3.13154087, ..., 3.13154087, 3.13154087,
#           3.13154087]]),
#   'intensity': array([[3.25e+12, 3.25e+12, 3.25e+12, ..., 3.25e+12, 3.25e+12, 3.25e+12]]),
#   'kurtosis_dE': array([[-0.84980452, -0.84977926, -0.84975611, ..., -0.87834832,
#           -0.8782044 , -0.87806051]]),
#   'kurtosis_dE_6sig': array([[-0.84980452, -0.84977926, -0.84975611, ..., -0.87834832,
#           -0.8782044 , -0.87806051]]),
#   'kurtosis_x': array([[-0.21791537, -0.25010888, -0.29635281, ..., -0.27909069,
#           -0.27544811, -0.28066741]]),
#   'kurtosis_x_6sig': array([[-0.21791537, -0.25010888, -0.29635281, ..., -0.27909069,
#           -0.27544811, -0.28066741]]),
#   'kurtosis_xp': array([[-0.00704901,  0.01204781,  0.00492206, ..., -0.1434334 ,
#           -0.1436979 , -0.14627164]]),
#   'kurtosis_xp_6sig': array([[-0.00704901,  0.01204781,  0.00492206, ..., -0.1434334 ,
#           -0.1436979 , -0.14627164]]),
#   'kurtosis_y': array([[ 0.00575688,  0.02235183, -0.08229791, ...,  0.03874491,
#            0.24835437,  0.02243376]]),
#   'kurtosis_y_6sig': array([[ 0.00575688,  0.02235183, -0.08229791, ..., -0.19405638,
#           -0.19610517, -0.19835621]]),
#   'kurtosis_yp': array([[-0.00495551, -0.03900828,  0.08266872, ...,  0.64277938,
#            0.31610462,  0.61538727]]),
#   'kurtosis_yp_6sig': array([[-0.00495551, -0.03900828,  0.08266872, ..., -0.00117428,
#           -0.00611413, -0.01126616]]),
#   'kurtosis_z': array([[-0.87050572, -0.87052398, -0.87053736, ..., -0.84142956,
#           -0.84154006, -0.84165149]]),
#   'kurtosis_z_6sig': array([[-0.87050572, -0.87052398, -0.87053736, ..., -0.84142956,
#           -0.84154006, -0.84165149]]),
#   'max_dE': array([[0.00721458, 0.00721548, 0.00721562, ..., 0.00701773, 0.00701075,
#           0.00700359]]),
#   'max_x': array([[0.02409271, 0.02099848, 0.02100711, ..., 0.02230714, 0.0208708 ,
#           0.02122239]]),
#   'max_xp': array([[0.00083337, 0.00085283, 0.00086118, ..., 0.00082192, 0.00086318,
#           0.00091407]]),
#   'max_y': array([[0.01325797, 0.01281699, 0.01393097, ..., 0.04295292, 0.02721614,
#           0.04250959]]),
#   'max_yp': array([[0.000979  , 0.00100172, 0.00098219, ..., 0.00199891, 0.00351757,
#           0.00451566]]),
#   'max_z': array([[19.13667816, 19.12301431, 19.12556669, ..., 21.39621782,
#           21.38821163, 21.37953614]]),
#   'mean_dE': array([[-7.90922224e-06, -7.86384856e-06, -7.81782359e-06, ...,
#            6.91019374e-06,  6.78959782e-06,  6.66931194e-06]]),
#   'mean_x': array([[-1.63001936e-05, -2.18987372e-05, -2.46852866e-05, ...,
#            2.35055974e-05, -1.03806157e-05, -3.45337147e-05]]),
#   'mean_xp': array([[-5.41178462e-09,  1.25530951e-08,  1.87599308e-07, ...,
#           -6.05312307e-07, -1.28206950e-06,  2.22206016e-08]]),
#   'mean_y': array([[-9.29607539e-06, -3.55849113e-07,  9.41162768e-06, ...,
#            2.82997840e-06,  2.57986333e-06, -2.98458909e-06]]),
#   'mean_yp': array([[ 9.74459257e-09,  7.40395202e-07, -9.88950372e-08, ...,
#            1.97050707e-07, -2.48085481e-07, -1.46805713e-07]]),
#   'mean_z': array([[-0.01575698, -0.01605454, -0.01635092, ...,  0.05241582,
#            0.0523876 ,  0.05236343]]),
#   'min_dE': array([[-0.00723948, -0.00724174, -0.0072446 , ..., -0.00715211,
#           -0.00715699, -0.00716146]]),
#   'min_x': array([[-0.02199041, -0.02358034, -0.02344413, ..., -0.02344858,
#           -0.02402605, -0.0216202 ]]),
#   'min_xp': array([[-0.0008289 , -0.00080306, -0.00082739, ..., -0.00088264,
#           -0.00084975, -0.0008144 ]]),
#   'min_y': array([[-0.01314663, -0.01265499, -0.01339958, ..., -0.04338192,
#           -0.05674617, -0.04250559]]),
#   'min_yp': array([[-0.00099807, -0.00097901, -0.00099831, ..., -0.00444055,
#           -0.0033383 , -0.0018535 ]]),
#   'min_z': array([[-19.12459947, -19.1226448 , -19.12210839, ..., -21.61905066,
#           -21.62752383, -21.63435938]]),
#   'mu_dE': array([[1.04220014e-05, 1.04219636e-05, 1.04217803e-05, ...,
#           9.67995599e-06, 9.67928363e-06, 9.67857855e-06]]),
#   'mu_x': array([[2.73997294e-05, 2.87435513e-05, 2.95336149e-05, ...,
#           2.78231413e-05, 2.77819024e-05, 2.78584572e-05]]),
#   'mu_xp': array([[3.02871073e-08, 3.01286154e-08, 3.23241929e-08, ...,
#           3.48847197e-08, 3.48451219e-08, 3.47493681e-08]]),
#   'mu_y': array([[8.11562640e-06, 8.49846364e-06, 9.52438661e-06, ...,
#           9.61146869e-06, 9.57297125e-06, 9.59152293e-06]]),
#   'mu_yp': array([[5.01725129e-08, 4.75267308e-08, 4.30826161e-08, ...,
#           4.98843887e-08, 5.01342419e-08, 4.99755222e-08]]),
#   'mu_z': array([[74.54358926, 74.54411175, 74.54598245, ..., 81.18215935,
#           81.1876393 , 81.19343346]]),
#   'n_mp': array([[500000, 500000, 500000, ..., 500000, 500000, 500000]]),
#   'sig_dE': array([[0.00322831, 0.00322831, 0.00322828, ..., 0.00311126, 0.00311115,
#           0.00311104]]),
#   'sig_x': array([[0.00523448, 0.0053613 , 0.00543448, ..., 0.00527476, 0.00527085,
#           0.00527811]]),
#   'sig_xp': array([[0.00017403, 0.00017358, 0.00017979, ..., 0.00018677, 0.00018667,
#           0.00018641]]),
#   'sig_y': array([[0.00284879, 0.00291521, 0.00308616, ..., 0.00310024, 0.00309402,
#           0.00309702]]),
#   'sig_yp': array([[0.00022399, 0.00021801, 0.00020756, ..., 0.00022335, 0.00022391,
#           0.00022355]]),
#   'sig_z': array([[8.63386294, 8.6338932 , 8.63400153, ..., 9.01011428, 9.01041838,
#           9.0107399 ]]),
#   'turn': array([[  -1,    0,    1, ..., 8997, 8998, 8999]]),
#   'turn_duration': array([[1.89065933e-04, 9.43522611e+01, 9.40615690e+01, ...,
#           9.28827870e+01, 9.29592249e+01, 9.29720039e+01]]),
#   'turn_time': array([u'17:47:24', u'17:48:58', u'17:50:42', ..., u'14:54:28',
#          u'14:56:01', u'14:57:34'], dtype='<U8')},
#  '5 %': {'D_x': array([[3.08868431, 3.20732663, 3.35802474, ..., 3.22721306, 3.22398179,
#           3.22513439]]),
#   'D_y': array([[-0.0024603 , -0.00178954, -0.00099809, ..., -0.00065121,
#            0.00302591,  0.00576843]]),
#   '__globals__': [],
#   '__header__': 'MATLAB 5.0 MAT-file Platform: posix, Created on: Thu Feb 27 22:45:54 2020',
#   '__version__': '1.0',
#   'alpha_x': array([[0.01239573, 0.04750815, 0.07824199, ..., 0.02756057, 0.02602609,
#           0.02760477]]),
#   'alpha_y': array([[ 0.08050199, -0.01192977,  0.03690659, ...,  0.06404381,
#            0.06248829,  0.06093128]]),
#   'beta_x': array([[21.7967186 , 21.9831373 , 21.31138497, ..., 21.15451352,
#           21.18930775, 21.22287204]]),
#   'beta_y': array([[12.20401092, 12.87595641, 13.73256313, ..., 13.09410746,
#           13.04924883, 13.09139323]]),
#   'bunchlength': array([[1.21601181e-07, 1.21601534e-07, 1.21603018e-07, ...,
#           1.26703424e-07, 1.26713986e-07, 1.26724802e-07]]),
#   'cumulative_time': array([[1.81913376e-04, 7.26680360e+01, 1.55069880e+02, ...,
#           2.21215998e+05, 2.21288596e+05, 2.21360993e+05]]),
#   'dpp_rms': array([[0.00122583, 0.00122583, 0.00122583, ..., 0.00118318, 0.00118309,
#           0.00118299]]),
#   'eff_alpha_x': array([[0.04882678, 0.04624683, 0.08300662, ..., 0.06653609, 0.06452627,
#           0.06465131]]),
#   'eff_alpha_y': array([[ 0.0805017 , -0.01192964,  0.03690658, ...,  0.06404418,
#            0.06248601,  0.06092987]]),
#   'eff_beta_x': array([[31.09477468, 31.91327237, 31.96779998, ..., 30.08423324,
#           30.1050365 , 30.14762967]]),
#   'eff_beta_y': array([[12.20401754, 12.87596001, 13.73256429, ..., 13.094085  ,
#           13.04923553, 13.09142386]]),
#   'eff_epsn_x': array([[9.05581356e-07, 9.21347994e-07, 9.53327613e-07, ...,
#           9.57968617e-07, 9.57004340e-07, 9.56596017e-07]]),
#   'eff_epsn_y': array([[6.33274098e-07, 6.33926322e-07, 6.36651078e-07, ...,
#           6.90783637e-07, 6.90852076e-07, 6.90878981e-07]]),
#   'eps_z': array([[1.23564943, 1.23565011, 1.23565124, ..., 1.24255793, 1.24255458,
#           1.24255098]]),
#   'epsn_x': array([[1.88203487e-06, 1.88253287e-06, 1.88423181e-06, ...,
#           1.99756553e-06, 1.99742799e-06, 1.99713113e-06]]),
#   'epsn_y': array([[1.87929219e-06, 1.88122833e-06, 1.88931469e-06, ...,
#           2.04995406e-06, 2.05015580e-06, 2.05023489e-06]]),
#   'gamma': array([[3.13154087, 3.13154087, 3.13154087, ..., 3.13154087, 3.13154087,
#           3.13154087]]),
#   'intensity': array([[3.25e+12, 3.25e+12, 3.25e+12, ..., 3.25e+12, 3.25e+12, 3.25e+12]]),
#   'kurtosis_dE': array([[-0.85350741, -0.85349533, -0.85348522, ..., -0.87718652,
#           -0.876962  , -0.87673803]]),
#   'kurtosis_dE_6sig': array([[-0.85350741, -0.85349533, -0.85348522, ..., -0.87718652,
#           -0.876962  , -0.87673803]]),
#   'kurtosis_x': array([[-0.22295559, -0.25694432, -0.28020165, ..., -0.28073158,
#           -0.2860052 , -0.28343778]]),
#   'kurtosis_x_6sig': array([[-0.22295559, -0.25694432, -0.28020165, ..., -0.28073158,
#           -0.2860052 , -0.28343778]]),
#   'kurtosis_xp': array([[ 0.00328029,  0.002772  ,  0.0003958 , ..., -0.1286711 ,
#           -0.13357758, -0.13593283]]),
#   'kurtosis_xp_6sig': array([[ 0.00328029,  0.002772  ,  0.0003958 , ..., -0.1286711 ,
#           -0.13357758, -0.13593283]]),
#   'kurtosis_y': array([[-0.01126053,  0.02410119, -0.06817129, ..., -0.2502774 ,
#           -0.25596591, -0.25182588]]),
#   'kurtosis_y_6sig': array([[-0.01126053,  0.02410119, -0.06817129, ..., -0.2502774 ,
#           -0.25596591, -0.25182588]]),
#   'kurtosis_yp': array([[ 0.00912397, -0.04048812,  0.07954291, ..., -0.12159219,
#           -0.12020107, -0.13299632]]),
#   'kurtosis_yp_6sig': array([[ 0.00912397, -0.04048812,  0.07954291, ..., -0.12159219,
#           -0.12020107, -0.13299632]]),
#   'kurtosis_z': array([[-0.86549986, -0.86547683, -0.8654501 , ..., -0.84164288,
#           -0.84177243, -0.84190178]]),
#   'kurtosis_z_6sig': array([[-0.86549986, -0.86547683, -0.8654501 , ..., -0.84164288,
#           -0.84177243, -0.84190178]]),
#   'max_dE': array([[0.00721456, 0.00721523, 0.00721869, ..., 0.00720038, 0.00720137,
#           0.00720213]]),
#   'max_x': array([[0.02201923, 0.02246228, 0.02543664, ..., 0.02248352, 0.02128316,
#           0.02399125]]),
#   'max_xp': array([[0.00082709, 0.00081778, 0.00077056, ..., 0.00085321, 0.0007643 ,
#           0.00086677]]),
#   'max_y': array([[0.0125477 , 0.01362239, 0.01348116, ..., 0.01664257, 0.01396138,
#           0.01283175]]),
#   'max_yp': array([[0.00109365, 0.00099278, 0.00106841, ..., 0.00110654, 0.00110355,
#           0.00101866]]),
#   'max_z': array([[19.13518267, 19.14000071, 19.14432867, ..., 21.27089664,
#           21.27754387, 21.28318687]]),
#   'mean_dE': array([[-1.05021498e-05, -1.05918814e-05, -1.06807272e-05, ...,
#            1.43124157e-05,  1.42645725e-05,  1.42163103e-05]]),
#   'mean_x': array([[-1.39502064e-05, -2.13196413e-05, -3.05803716e-05, ...,
#            7.56508192e-06,  3.05980671e-05,  1.79408777e-05]]),
#   'mean_xp': array([[ 5.11651746e-09, -2.77551901e-07, -1.11474873e-07, ...,
#            1.20331977e-06,  2.76732007e-07, -9.87277118e-07]]),
#   'mean_y': array([[-7.68637278e-07,  6.27907248e-06,  4.67124346e-07, ...,
#           -4.25429081e-06,  4.56604327e-06,  4.20892238e-06]]),
#   'mean_yp': array([[ 5.20589484e-07,  7.23633051e-09, -5.18974916e-07, ...,
#            4.00421147e-07,  3.18679619e-07, -3.97751687e-07]]),
#   'mean_z': array([[0.03543807, 0.03509083, 0.03474331, ..., 0.0221371 , 0.02224077,
#           0.02234228]]),
#   'min_dE': array([[-0.00723587, -0.00723582, -0.00723966, ..., -0.00694703,
#           -0.0069508 , -0.00695428]]),
#   'min_x': array([[-0.02409084, -0.02176717, -0.02173147, ..., -0.02240269,
#           -0.02436115, -0.02377613]]),
#   'min_xp': array([[-0.00077466, -0.00076881, -0.00077381, ..., -0.0007795 ,
#           -0.0007335 , -0.00073725]]),
#   'min_y': array([[-0.01156245, -0.01374578, -0.01372665, ..., -0.01368403,
#           -0.012771  , -0.01460399]]),
#   'min_yp': array([[-0.00110186, -0.0009745 , -0.00111339, ..., -0.00112224,
#           -0.00133464, -0.00108441]]),
#   'min_z': array([[-19.13771317, -19.13939241, -19.13888299, ..., -21.60534227,
#           -21.60047847, -21.59449528]]),
#   'mu_dE': array([[1.04620316e-05, 1.04620400e-05, 1.04618994e-05, ...,
#           9.74666889e-06, 9.74508971e-06, 9.74346925e-06]]),
#   'mu_x': array([[2.81588482e-05, 2.94032295e-05, 3.04757865e-05, ...,
#           2.88197513e-05, 2.88106506e-05, 2.88391025e-05]]),
#   'mu_xp': array([[2.91926962e-08, 2.89321175e-08, 3.00269689e-08, ...,
#           3.19838497e-08, 3.19212023e-08, 3.18630154e-08]]),
#   'mu_y': array([[7.72848820e-06, 8.16240997e-06, 8.74285186e-06, ...,
#           9.04517966e-06, 9.01509146e-06, 9.04458958e-06]]),
#   'mu_yp': array([[5.22269035e-08, 4.92403316e-08, 4.64238320e-08, ...,
#           5.29717804e-08, 5.31486697e-08, 5.29693211e-08]]),
#   'mu_z': array([[74.59102227, 74.59145525, 74.59327542, ..., 80.98184669,
#           80.99534821, 81.00917664]]),
#   'n_mp': array([[500000, 500000, 500000, ..., 500000, 500000, 500000]]),
#   'sig_dE': array([[0.00323451, 0.00323451, 0.00323449, ..., 0.00312197, 0.00312171,
#           0.00312145]]),
#   'sig_x': array([[0.00530649, 0.00542247, 0.00552049, ..., 0.0053684 , 0.00536756,
#           0.00537021]]),
#   'sig_xp': array([[0.00017086, 0.00017009, 0.00017328, ..., 0.00017884, 0.00017867,
#           0.0001785 ]]),
#   'sig_y': array([[0.00278002, 0.00285699, 0.00295683, ..., 0.00300752, 0.00300251,
#           0.00300742]]),
#   'sig_yp': array([[0.00022853, 0.0002219 , 0.00021546, ..., 0.00023016, 0.00023054,
#           0.00023015]]),
#   'sig_z': array([[8.63660942, 8.63663449, 8.63673986, ..., 8.99899143, 8.99974156,
#           9.0005098 ]]),
#   'turn': array([[  -1,    0,    1, ..., 8997, 8998, 8999]]),
#   'turn_duration': array([[1.79052353e-04, 7.26677761e+01, 7.25433660e+01, ...,
#           7.23694201e+01, 7.25975020e+01, 7.23965659e+01]]),
#   'turn_time': array([u'17:53:48', u'17:55:01', u'17:56:23', ..., u'22:43:19',
#          u'22:44:32', u'22:45:44'], dtype='<U8')}}

# %%
dd['0 %'].keys()
# Out:
# ['eps_z',
#  'D_x',
#  'D_y',
#  'kurtosis_yp_6sig',
#  'kurtosis_yp',
#  'mu_yp',
#  'kurtosis_z_6sig',
#  'eff_beta_y',
#  'eff_beta_x',
#  'eff_alpha_y',
#  'kurtosis_y_6sig',
#  'epsn_y',
#  'epsn_x',
#  'beta_y',
#  'beta_x',
#  'dpp_rms',
#  'sig_yp',
#  'min_dE',
#  'turn_time',
#  'n_mp',
#  'min_xp',
#  'kurtosis_y',
#  'kurtosis_xp_6sig',
#  'alpha_x',
#  'alpha_y',
#  'bunchlength',
#  '__header__',
#  'sig_xp',
#  'kurtosis_dE_6sig',
#  'max_xp',
#  'intensity',
#  'min_yp',
#  'sig_dE',
#  'min_x',
#  'min_y',
#  'mu_y',
#  'mu_x',
#  'cumulative_time',
#  'mean_yp',
#  'kurtosis_xp',
#  'eff_epsn_y',
#  'eff_epsn_x',
#  'mean_x',
#  'mean_y',
#  'mean_z',
#  'kurtosis_x_6sig',
#  '__version__',
#  'max_z',
#  'mu_dE',
#  'max_x',
#  'max_y',
#  'mean_dE',
#  'sig_z',
#  'sig_y',
#  'sig_x',
#  'max_yp',
#  'kurtosis_z',
#  'eff_alpha_x',
#  'kurtosis_x',
#  'mu_xp',
#  'turn_duration',
#  'mu_z',
#  'mean_xp',
#  'min_z',
#  'kurtosis_dE',
#  '__globals__',
#  'turn',
#  'max_dE',
#  'gamma']

# %%
parameter = 'sig_x'
multi = 1E3

fig1 = plt.figure(facecolor='w', edgecolor='k')
ax1 = fig1.add_subplot(111)

tit = main_label + ' ' + sc + ' ' + parameter
ax1.set_title(tit);

ax1.set_ylabel(r'$\sigma_x$ [mm]');
ax1.set_xlabel('Turn [-]');

colors = cm.rainbow(np.linspace(0, 1, len(dd.keys())))
c_it = int(0)

for key, value in sorted(dd.iteritems()):
    ax1.plot(dd[key]['turn'][0], dd[key][parameter][0]*multi, label=key, color=colors[c_it]);
    c_it = c_it + 1;
        
ax1.legend(loc=3, title=legend_label)
ax1.grid(lw=0.5, ls=':');
ax1.set_xlim(-1,turn_tot)

fig1.tight_layout()

savename = save_folder + '/'+ main_label + '_' + parameter + '.png'
plt.savefig(savename, dpi = 800);

# %%
parameter = 'sig_x'
multi = 1E3

fig1 = plt.figure(facecolor='w', edgecolor='k')
ax1 = fig1.add_subplot(111)
ax2 = ax1.twinx()

tit = main_label + ' ' + sc + ' ' + parameter
ax1.set_title(tit);

ax1.set_ylabel(r'$\sigma_x$ [mm]');
ax2.set_ylabel(r'$\left(\frac{\delta p}{p_0}\right)_{RMS}$ [1E-3]');
ax1.set_xlabel('Turn [-]');

colors = cm.rainbow(np.linspace(0, 1, len(dd.keys())))
c_it = int(0)

for key, value in sorted(dd.iteritems()):
    ax1.plot(dd[key]['turn'][0], dd[key][parameter][0]*multi, label=key, color=colors[c_it], ls='-');
    ax2.plot(dd[key]['turn'][0], dd[key]['dpp_rms'][0]*multi, color=colors[c_it], ls=':');
    c_it = c_it + 1;
    

        
ax1.legend(loc=4, title=legend_label)
ax1.grid(lw=0.5, ls=':');
#ax1.set_xlim(-1,3000)
ax2.set_ylim(1.0, 1.25)
ax1.set_ylim(5.0, 6.0)

custom_lines = [Line2D([0], [0], color='k', lw=4, linestyle='-'),
                Line2D([0], [0], color='k', lw=4, linestyle=':'),
                Line2D([0], [0], color='b', lw=4, linestyle='--')]

ax2.legend(custom_lines, [r'$\left(\frac{\delta p}{p_0}\right)_{RMS}$',r'$\sigma_x$', r'$\frac{1}{Q_s}$'], loc=1)

ax1.vlines(500, 5, 6, colors='b', linestyles='solid', label='', lw=0.5, linestyle='--')
ax1.vlines(500+520, 5, 6, colors='b', linestyles='solid', label='', lw=0.5, linestyle='--')
ax1.vlines(500+520+520, 5, 6, colors='b', linestyles='solid', label='', lw=0.5, linestyle='--')

fig1.tight_layout()

savename = save_folder + '/'+ main_label + '_Sigma_cf_RF.png'
plt.savefig(savename, dpi = 800);

# %%
parameter = 'sig_y'
multi = 1E3

fig1 = plt.figure(facecolor='w', edgecolor='k')
ax1 = fig1.add_subplot(111)

tit = main_label + ' ' + sc + ' ' + parameter
ax1.set_title(tit);

ax1.set_ylabel(r'$\sigma_y$ [mm]');
ax1.set_xlabel('Turn [-]');

colors = cm.rainbow(np.linspace(0, 1, len(dd.keys())))
c_it = int(0)

for key, value in sorted(dd.iteritems()):
    ax1.plot(dd[key]['turn'][0], dd[key][parameter][0]*multi, label=key, color=colors[c_it]);
    c_it = c_it + 1;
        
ax1.legend(loc=3, title=legend_label)
ax1.grid(lw=0.5, ls=':');
ax1.set_xlim(-1,turn_tot)

fig1.tight_layout()

savename = save_folder + '/'+ main_label + '_' + parameter + '.png'
plt.savefig(savename, dpi = 800);

# %%
parameter = 'dpp_rms'
multi = 1E3

fig1 = plt.figure(facecolor='w', edgecolor='k')
ax1 = fig1.add_subplot(111)

tit = main_label + ' ' + sc + ' ' + parameter
ax1.set_title(tit);

ax1.set_ylabel(r'$\left(\frac{\delta p}{p_0}\right)_{RMS}$ [1E-3]');
ax1.set_xlabel('Turn [-]');

colors = cm.rainbow(np.linspace(0, 1, len(dd.keys())))
c_it = int(0)

for key, value in sorted(dd.iteritems()):
    ax1.plot(dd[key]['turn'][0], dd[key][parameter][0]*multi, label=key, color=colors[c_it]);
    c_it = c_it + 1;
        
ax1.legend(loc=3, title=legend_label)
ax1.grid(lw=0.5, ls=':');
ax1.set_xlim(-1,turn_tot)

#ax1.set_ylim(1.63, 1.71)

fig1.tight_layout()

savename = save_folder + '/'+ main_label + '_' + parameter + '.png'
plt.savefig(savename, dpi = 800);

# %%
parameter = 'sig_x'
multi = 1E3

fig1 = plt.figure(facecolor='w', edgecolor='k')
ax1 = fig1.add_subplot(111)
ax2 = ax1.twinx()

tit = main_label + ' ' + sc + ' ' + parameter
ax1.set_title(tit);

ax1.set_ylabel(r'$\sigma_x$ [mm]');
ax2.set_ylabel(r'$\left(\frac{\delta p}{p_0}\right)_{RMS}$ [1E-3]');
ax1.set_xlabel('Turn [-]');

colors = cm.rainbow(np.linspace(0, 1, len(dd.keys())))
c_it = int(0)

for key, value in sorted(dd.iteritems()):
    ax1.plot(dd[key]['turn'][0], dd[key][parameter][0]*multi, label=key, color=colors[c_it], ls='-');
    ax2.plot(dd[key]['turn'][0], dd[key]['dpp_rms'][0]*multi, color=colors[c_it], ls=':');
    c_it = c_it + 1;
    

        
ax1.legend(loc=3, title=legend_label, fontsize='small')
ax1.grid(lw=0.5, ls=':');
ax1.set_xlim(-1,3200)
ax2.set_ylim(1.52, 1.8)
ax1.set_ylim(6.4, 7.4)

q_s = 1.85E-3
f_s = 1/q_s
peak_turn = 740
ax1.vlines(peak_turn-f_s, 6, 10, colors='k', linestyles='solid', label='', lw=0.5, linestyle='--')
ax1.vlines(peak_turn, 6, 10, colors='k', linestyles='solid', label='', lw=0.5, linestyle='--')
ax1.vlines(peak_turn+f_s, 6, 10, colors='k', linestyles='solid', label='', lw=0.5, linestyle='--')
ax1.vlines(peak_turn+f_s+f_s, 6, 10, colors='k', linestyles='solid', label='', lw=0.5, linestyle='--')
ax1.vlines(peak_turn+f_s+f_s+f_s, 6, 10, colors='k', linestyles='solid', label='', lw=0.5, linestyle='--')
ax1.vlines(peak_turn+f_s+f_s+f_s+f_s, 6, 10, colors='k', linestyles='solid', label='', lw=0.5, linestyle='--')

custom_lines = [Line2D([0], [0], color='r', lw=4, linestyle='-'),
                Line2D([0], [0], color='r', lw=4, linestyle=':'),
                Line2D([0], [0], color='k', lw=4, linestyle='--')]

lab3 = r'$\frac{1}{Q_s}\approx$ ' + str(round_sig(f_s,3)) + ' turns'
ax2.legend(custom_lines, [r'$\sigma_x$', r'$\left(\frac{\delta p}{p_0}\right)_{RMS}$',lab3], loc=1, fontsize='small')

fig1.tight_layout()

savename = save_folder + '/sig_x_synch_period.png'
plt.savefig(savename, dpi = 800);

print 'Synchroton period looks like ', round_sig(f_s,3), ' turns'
# Out:
# Synchroton period looks like  541.0  turns

# %%
for key, value in sorted(dd.iteritems()):
    print '\n', key, ' bunch length deviation +/- ', round_sig((np.max(dd[key]['bunchlength'][0]*1E9) - np.min(dd[key]['bunchlength'][0]*1E9))/2,3), 'ns'
# Out:
# 0 %  bunch length deviation +/-  6.65 ns
#
# 10 %  bunch length deviation +/-  6.5 ns
#
# 5 %  bunch length deviation +/-  6.62 ns

# %%
parameter = 'bunchlength'
multi = 1E9

fig1 = plt.figure(facecolor='w', edgecolor='k')
ax1 = fig1.add_subplot(111)

tit = main_label + ' ' + sc + ' ' + parameter
ax1.set_title(tit);

ax1.set_ylabel(r'$B_l$ [ns]');
ax1.set_xlabel('Turn [-]');

colors = cm.rainbow(np.linspace(0, 1, len(dd.keys())))
c_it = int(0)

for key, value in sorted(dd.iteritems()):
    ax1.plot(dd[key]['turn'][0], dd[key][parameter][0]*multi, label=key, color=colors[c_it]);
    c_it = c_it + 1;
    
ax2 = ax1.twinx()
ax2.plot((dd[key][parameter][0]*multi/np.mean(dd[key][parameter][0]*multi)*100)-100, color='r', alpha=0)
ax2.set_ylabel(r'$\frac{B_L}{\left< B_L \right>}$ [%]')

ax1.legend(loc=3, title=legend_label)
ax1.grid(lw=0.5, ls=':');
ax1.set_xlim(-1,turn_tot)

fig1.tight_layout()

savename = save_folder + '/'+ main_label + '_' + parameter + '.png'
plt.savefig(savename, dpi = 800);

# %%
parameter = 'beta_x'
multi = 1

fig1 = plt.figure(facecolor='w', edgecolor='k')
ax1 = fig1.add_subplot(111)

tit = main_label + ' ' + sc + ' ' + parameter
ax1.set_title(tit);

ax1.set_ylabel(r'$\beta_{x}$ [m]');
ax1.set_xlabel('Turn [-]');

colors = cm.rainbow(np.linspace(0, 1, len(dd.keys())))
c_it = int(0)

for key, value in sorted(dd.iteritems()):
    ax1.plot(dd[key]['turn'][0], dd[key][parameter][0]*multi, label=key, color=colors[c_it]);
    c_it = c_it + 1;
        
ax1.legend(loc=3, title=legend_label)
ax1.grid(lw=0.5, ls=':');
#ax1.set_xlim(-1,turn_tot)

fig1.tight_layout()

savename = save_folder + '/'+ main_label + '_' + parameter + '.png'
plt.savefig(savename, dpi = 800);

# %%
parameter = 'beta_y'
multi = 1

fig1 = plt.figure(facecolor='w', edgecolor='k')
ax1 = fig1.add_subplot(111)

tit = main_label + ' ' + sc + ' ' + parameter
ax1.set_title(tit);

ax1.set_ylabel(r'$\beta_{y}$ [m]');
ax1.set_xlabel('Turn [-]');

colors = cm.rainbow(np.linspace(0, 1, len(dd.keys())))
c_it = int(0)

for key, value in sorted(dd.iteritems()):
    ax1.plot(dd[key]['turn'][0], dd[key][parameter][0]*multi, label=key, color=colors[c_it]);
    c_it = c_it + 1;
        
ax1.legend(loc=3, title=legend_label)
ax1.grid(lw=0.5, ls=':');
#ax1.set_xlim(-1,turn_tot)

fig1.tight_layout()

savename = save_folder + '/'+ main_label + '_' + parameter + '.png'
plt.savefig(savename, dpi = 800);

# %%
parameter = 'epsn_x'
multi = 1E6

fig1 = plt.figure(facecolor='w', edgecolor='k')
ax1 = fig1.add_subplot(111)

tit = main_label + ' ' + sc + ' ' + parameter
ax1.set_title(tit);

ax1.set_ylabel(r'$\epsilon_{x_{RMS}}$ [mm mrad]');
ax1.set_xlabel('Turn [-]');

colors = cm.rainbow(np.linspace(0, 1, len(dd.keys())))
c_it = int(0)

for key, value in sorted(dd.iteritems()):
    ax1.plot(dd[key]['turn'][0], dd[key][parameter][0]*multi, label=key, color=colors[c_it]);
    av_ = np.mean(dd[key][parameter][0][-100]*multi)
    rang_ = np.abs(np.mean(dd[key][parameter][0][-100:]*multi) - np.mean(dd[key][parameter][0][:5]*multi))
    print key, 'Average ', parameter, ' in last 100 turns = ' , \
    str(round_sig(av_)), ' range = ', round_sig(rang_), ' = ', round_sig(rang_/av_)*100, '%'    
    c_it = c_it + 1;
        
ax1.legend(loc=2, title=legend_label)
ax1.grid(lw=0.5, ls=':');
#ax1.set_xlim(-1,turn_tot)

fig1.tight_layout()

savename = save_folder + '/'+ main_label + '_' + parameter + '.png'
plt.savefig(savename, dpi = 800);
# Out:
# 0 % Average  epsn_x  in last 100 turns =  1.952  range =  0.07492  =  3.839 %
# 10 % Average  epsn_x  in last 100 turns =  2.033  range =  0.1389  =  6.83 %
# 5 % Average  epsn_x  in last 100 turns =  1.994  range =  0.1106  =  5.544 %

# %%
parameter = 'epsn_y'
multi = 1E6

fig1 = plt.figure(facecolor='w', edgecolor='k')
ax1 = fig1.add_subplot(111)

tit = main_label + ' ' + sc + ' ' + parameter
ax1.set_title(tit);

ax1.set_ylabel(r'$\epsilon_{y_{RMS}}$ [mm mrad]');
ax1.set_xlabel('Turn [-]');

colors = cm.rainbow(np.linspace(0, 1, len(dd.keys())))
c_it = int(0)

for key, value in sorted(dd.iteritems()):
    ax1.plot(dd[key]['turn'][0], dd[key][parameter][0]*multi, label=key, color=colors[c_it]);
    av_ = np.mean(dd[key][parameter][0][-100]*multi)
    rang_ = np.abs(np.mean(dd[key][parameter][0][-100:]*multi) - np.mean(dd[key][parameter][0][:5]*multi))
    print key, 'Average ', parameter, ' in last 100 turns = ' , \
    str(round_sig(av_)), ' range = ', round_sig(rang_), ' = ', round_sig(rang_/av_)*100, '%'    
    c_it = c_it + 1;
        
        
ax1.legend(loc=2, title=legend_label)
ax1.grid(lw=0.5, ls=':');
ax1.set_ylim(1.85, 2.25)

fig1.tight_layout()

savename = save_folder + '/'+ main_label + '_' + parameter + '.png'
plt.savefig(savename, dpi = 800);
# Out:
# 0 % Average  epsn_y  in last 100 turns =  2.052  range =  0.1691  =  8.24 %
# 10 % Average  epsn_y  in last 100 turns =  2.048  range =  0.1525  =  7.446 %
# 5 % Average  epsn_y  in last 100 turns =  2.051  range =  0.1613  =  7.866 %

# %%
print 'Vertical Emittance growth = ', round_sig(100*((1/(dd[41.2]['epsn_y'][0][0]/dd[41.2]['epsn_y'][0][-1]))-1),3), '%'
# Out:
# Vertical Emittance growth =
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-0fd28c156da0> in <module>()
# ----> 1 print 'Vertical Emittance growth = ', round_sig(100*((1/(dd[41.2]['epsn_y'][0][0]/dd[41.2]['epsn_y'][0][-1]))-1),3), '%'
#
# KeyError: 41.2

# %%
##### parameter1 = 'epsn_x'
parameter2 = 'epsn_y'
multi1 = 1E6
multi2 = 1E6

fig1 = plt.figure(facecolor='w', edgecolor='k')
ax1 = fig1.add_subplot(111)

tit = main_label + ' ' + sc + ' average emittance'
ax1.set_title(tit);

ax1.set_ylabel(r'$\frac{\epsilon_{x_{RMS}} + \epsilon_{y_{RMS}}}{2}$ [mm mrad]');
ax1.set_xlabel('Turn [-]');

colors = cm.rainbow(np.linspace(0, 1, len(dd.keys())))
c_it = int(0)


for key, value in sorted(dd.iteritems()):
    ax1.plot(dd[key]['turn'][0], (dd[key][parameter1][0]*multi1 + dd[key][parameter2][0]*multi2)/2, label=key, color=colors[c_it]);
    av_ = (np.mean(dd[key][parameter1][0][-100]*multi1) + np.mean(dd[key][parameter2][0][-100]*multi2))/2
    start_x = np.mean(dd[key][parameter1][0][:5]*multi1)
    start_y = np.mean(dd[key][parameter2][0][:5]*multi2)
    rang_ = np.abs(av_  - ((start_x + start_y)/2) )
    print key, 'Mean average emittance in last 100 turns = ' , \
    str(round_sig(av_)), ' range = ', round_sig(rang_), ' = ', round_sig(rang_/av_)*100, '%'    
    c_it = c_it + 1;
        
        
ax1.legend(loc=2, title=legend_label);
ax1.grid(lw=0.5, ls=':');
#ax1.set_xlim(-1,turn_tot);

fig1.tight_layout()
savename = save_folder + '/'+ main_label + '_epsn_av.png'
plt.savefig(savename, dpi = 800);
# Out:
# 0 % Mean average emittance in last 100 turns =  2.002  range =  0.1216  =  6.076 %
# 10 % Mean average emittance in last 100 turns =  2.041  range =  0.1451  =  7.111 %
# 5 % Mean average emittance in last 100 turns =  2.023  range =  0.1356  =  6.703 %

# %%
parameter = 'D_x'
multi = 1

fig1 = plt.figure(facecolor='w', edgecolor='k')
ax1 = fig1.add_subplot(111)

tit = main_label + ' ' + sc + ' ' + parameter
ax1.set_title(tit);

ax1.set_ylabel(r'$D_{x}$ [m]');
ax1.set_xlabel('Turn [-]');

colors = cm.rainbow(np.linspace(0, 1, len(dd.keys())))
c_it = int(0)

for key, value in sorted(dd.iteritems()):
    ax1.plot(dd[key]['turn'][0], dd[key][parameter][0]*multi, label=key, color=colors[c_it]);
    c_it = c_it + 1;
        
ax1.legend(loc=3)
ax1.grid(lw=0.5, ls=':');
#ax1.set_xlim(-1,turn_tot)

fig1.tight_layout()

savename = save_folder + '/'+ main_label + '_' + parameter + '.png'
plt.savefig(savename, dpi = 800);

# %%
parameter = 'D_y'
multi = 1

fig1 = plt.figure(facecolor='w', edgecolor='k')
ax1 = fig1.add_subplot(111)

tit = main_label + ' ' + sc + ' ' + parameter
ax1.set_title(tit);

ax1.set_ylabel(r'$D_{y}$ [m]');
ax1.set_xlabel('Turn [-]');

colors = cm.rainbow(np.linspace(0, 1, len(dd.keys())))
c_it = int(0)

for key, value in sorted(dd.iteritems()):
    ax1.plot(dd[key]['turn'][0], dd[key][parameter][0]*multi, label=key, color=colors[c_it]);
    c_it = c_it + 1;
        
ax1.legend(loc=3)
ax1.grid(lw=0.5, ls=':');
#ax1.set_xlim(-1,turn_tot)

fig1.tight_layout()

savename = save_folder + '/'+ main_label + '_' + parameter + '.png'
plt.savefig(savename, dpi = 800);

# %%
dd['2021 Standard']['epsn_y'][0][1199]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-a8b3a23621f6> in <module>()
# ----> 1 dd['2021 Standard']['epsn_y'][0][1199]
#
# KeyError: '2021 Standard'

# %%
ep_0_21 = (dd['2021 Standard']['epsn_x'][0][0] + dd['2021 Standard']['epsn_y'][0][0])/2
ep_f_21 = (dd['2021 Standard']['epsn_x'][0][999] + dd['2021 Standard']['epsn_y'][0][999])/2
print '2021: epsn_av_0 = ', ep_0_21
print '2021: epsn_av_1000 = ', ep_f_21
print '2021: average emttance growth in 1000 turns = ', round_sig(((ep_f_21/ep_0_21)*100-100),3), '%'

# %%
ep_0_22 = (dd['2022 Standard']['epsn_x'][0][0] + dd['2022 Standard']['epsn_y'][0][0])/2
ep_f_22 = (dd['2022 Standard']['epsn_x'][0][999] + dd['2022 Standard']['epsn_y'][0][999])/2

print '2022: average emttance growth in 1000 turns = ', round_sig(((ep_f_22/ep_0_22)*100-100),3), '%'

# %%
ep_0_23 = (dd['2023 Standard']['epsn_x'][0][0] + dd['2023 Standard']['epsn_y'][0][0])/2
ep_f_23 = (dd['2023 Standard']['epsn_x'][0][999] + dd['2023 Standard']['epsn_y'][0][999])/2

print '2023: average emttance growth in 1000 turns = ', round_sig(((ep_f_23/ep_0_23)*100-100),3), '%'
